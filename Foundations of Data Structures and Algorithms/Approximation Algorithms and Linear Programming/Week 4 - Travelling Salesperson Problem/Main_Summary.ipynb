# %% [markdown]
# # **Travelling Salesperson Problem Approximation Schemes**

# %% [markdown]
# ![](2023-11-06-16-52-50.png)

# %% [markdown]
# ![](2023-11-06-16-54-40.png)

# %% [markdown]
# ![](2023-11-06-16-59-18.png)

# %% [markdown]
# ![](2023-11-06-17-01-56.png)

# %% [markdown]
# ![](2023-11-06-17-28-15.png)

# %% [markdown]
# ![](2023-11-06-17-36-47.png)

# %% [markdown]
# ![](2023-11-06-17-43-23.png)

# %% [markdown]
# ![](2023-11-06-21-42-50.png)

# %% [markdown]
# ![](2023-11-06-22-35-57.png)

# %% [markdown]
# ![](2023-11-06-23-07-39.png)

# %% [markdown]
# ![](2023-11-06-23-11-18.png)

# %% [markdown]
# ![](2023-11-06-23-14-11.png)

# %% [markdown]
# ![](2023-11-06-23-17-01.png)

# %% [markdown]
# ### **Integer Linear Programming Formulation**

# %% [markdown]
# ![](2023-11-06-23-45-23.png)

# %% [markdown]
# ![](2023-11-06-23-46-04.png)

# %% [markdown]
# ![](2023-11-06-23-47-26.png)

# %% [markdown]
# ![](2023-11-06-23-48-31.png)

# %% [markdown]
# ![](2023-11-06-23-49-18.png)

# %% [markdown]
# ![](2023-11-06-23-52-51.png)

# %% [markdown]
# ![](2023-11-07-06-45-14.png)

# %% [markdown]
# ![](2023-11-07-06-46-24.png)

# %% [markdown]
# ![](2023-11-06-23-55-18.png)

# %% [markdown]
# ![](2023-11-07-06-48-18.png)

# %% [markdown]
# ![](2023-11-07-06-48-58.png)

# %% [markdown]
# ![](2023-11-07-06-49-11.png)

# %% [markdown]
# ![](2023-11-07-06-49-47.png)

# %% [markdown]
# ### **Subtours and Subtour Elimination Formulation**

# %% [markdown]
# ![](2023-11-06-23-58-27.png)

# %% [markdown]
# ![](2023-11-07-06-52-03.png)

# %% [markdown]
# ![](2023-11-07-06-52-24.png)

# %% [markdown]
# ![](2023-11-07-06-53-29.png)

# %% [markdown]
# ![](2023-11-07-06-55-05.png)

# %% [markdown]
# ![](2023-11-07-06-55-53.png)

# %% [markdown]
# ![](2023-11-07-06-56-34.png)

# %% [markdown]
# ![](2023-11-07-06-57-10.png)

# %% [markdown]
# ![](2023-11-07-00-02-30.png)

# %% [markdown]
# ![](2023-11-07-06-58-20.png)

# %% [markdown]
# **Instead, you can**

# %% [markdown]
# ![](2023-11-07-07-01-43.png)

# %% [markdown]
# ![](2023-11-07-07-02-15.png)

# %% [markdown]
# ![](2023-11-07-07-02-31.png)

# %% [markdown]
# ![](2023-11-07-07-00-30.png)

# %% [markdown]
# ![](2023-11-07-07-03-37.png)

# %% [markdown]
# ![](2023-11-07-07-04-08.png)

# %% [markdown]
# ![](2023-11-07-00-04-38.png)

# %% [markdown]
# ## **Approximate Algorithms for TSP**

# %% [markdown]
# ### **Metric TSP and Shortcutting**

# %% [markdown]
# ![](2023-11-10-09-45-24.png)

# %% [markdown]
# ![](2023-11-10-09-46-06.png)

# %% [markdown]
# ![](2023-11-10-09-49-31.png)

# %% [markdown]
# ![](2023-11-10-09-51-11.png)

# %% [markdown]
# ![](2023-11-10-09-51-36.png)

# %% [markdown]
# ![](2023-11-10-09-52-08.png)

# %% [markdown]
# ![](2023-11-10-09-52-41.png)

# %% [markdown]
# ![](2023-11-10-09-53-06.png)

# %% [markdown]
# **The minimum spanning tree can be achievd by Kruskal's or Prim's (the better choice) algorithm. So we start by a minimum spanning tree, but the problem is that it is not a TSP tour:**

# %% [markdown]
# ![](2023-11-10-09-57-17.png)

# %% [markdown]
# **So we need to convert our MST to a TSP tour, a.k.a shorcutting.**

# %% [markdown]
# ![](2023-11-10-10-01-34.png)

# %% [markdown]
# ![](2023-11-10-10-02-11.png)

# %% [markdown]
# ![](2023-11-10-10-02-51.png)

# %% [markdown]
# ![](2023-11-10-10-03-25.png)

# %% [markdown]
# ![](2023-11-10-10-03-41.png)

# %% [markdown]
# ![](2023-11-10-10-04-30.png)

# %% [markdown]
# **Now, Let's consider another example. Starting by the MST of a graph, going from 1 -> 2 and since 2 is a deadend we backtrack to 1:**

# %% [markdown]
# ![](2023-11-10-10-07-27.png)

# %% [markdown]
# ![](2023-11-10-10-08-47.png)

# %% [markdown]
# ![](2023-11-10-10-11-15.png)

# %% [markdown]
# **Now 9 is a deadend, we need to backtrack to 4; we already visited 4 so we back track to 3:**

# %% [markdown]
# ![](2023-11-10-10-12-43.png)

# %% [markdown]
# **6 is a new node, therefore we shortcut from 9 to 6...**

# %% [markdown]
# ![](2023-11-10-10-18-44.png)

# %% [markdown]
# ![](2023-11-10-10-19-12.png)

# %% [markdown]
# ![](2023-11-10-10-19-30.png)

# %% [markdown]
# ![](2023-11-10-10-22-36.png)

# %% [markdown]
# ![](2023-11-10-10-34-27.png)

# %% [markdown]
# **And, by metric property, the cost of a shortcut must be less than or equal to the summation of the corresponding path in the tree.**

# %% [markdown]
# ![](2023-11-10-10-37-04.png)

# %% [markdown]
# ![](2023-11-10-10-37-29.png)

# %% [markdown]
# ![](2023-11-10-10-39-44.png)

# %% [markdown]
# ### **Eulerian Walks for approximating TSPs**

# %% [markdown]
# ![](2023-11-10-14-19-18.png)

# %% [markdown]
# ![](2023-11-10-14-20-18.png)

# %% [markdown]
# ![](2023-11-10-14-20-48.png)

# %% [markdown]
# ![](2023-11-10-14-21-16.png)

# %% [markdown]
# ![](2023-11-10-14-29-59.png)

# %% [markdown]
# ![](2023-11-10-14-31-08.png)

# %% [markdown]
# ![](2023-11-10-14-33-00.png)

# %% [markdown]
# ![](2023-11-10-14-38-37.png)

# %% [markdown]
# ### **Christofides Algorithm and its Analysis**

# %% [markdown]
# ![](2023-11-10-14-51-04.png)

# %% [markdown]
# ![](2023-11-10-14-51-29.png)

# %% [markdown]
# ![](2023-11-10-14-51-48.png)

# %% [markdown]
# ![](2023-11-10-14-52-05.png)

# %% [markdown]
# ![](2023-11-10-14-52-45.png)

# %% [markdown]
# ![](2023-11-10-14-53-26.png)

# %% [markdown]
# ![](2023-11-10-14-53-49.png)

# %% [markdown]
# ![](2023-11-10-14-54-49.png)

# %% [markdown]
# ![](2023-11-10-14-55-34.png)

# %% [markdown]
# ![](2023-11-10-14-55-53.png)

# %% [markdown]
# ![](2023-11-10-14-56-30.png)

# %% [markdown]
# ![](2023-11-10-14-57-14.png)

# %% [markdown]
# ![](2023-11-10-14-59-19.png)

# %% [markdown]
# ![](2023-11-10-15-00-05.png)

# %% [markdown]
# ![](2023-11-10-15-01-03.png)

# %% [markdown]
# ![](2023-11-10-15-01-27.png)

# %% [markdown]
# ![](2023-11-10-15-02-10.png)

# %% [markdown]
# ![](2023-11-10-15-03-35.png)

# %% [markdown]
# ![](2023-11-10-15-04-09.png)

# %% [markdown]
# ![](2023-11-10-15-04-45.png)

# %% [markdown]
# ![](2023-11-10-15-05-30.png)

# %% [markdown]
# ![](2023-11-10-15-05-46.png)

# %% [markdown]
# ![](2023-11-10-15-06-21.png)

# %% [markdown]
# ![](2023-11-10-15-07-13.png)

# %% [markdown]
# ![](2023-11-10-15-07-32.png)

# %% [markdown]
# ![](2023-11-10-15-08-30.png)

# %% [markdown]
# ## **Heuristics: A Brief Tour**

# %% [markdown]
# ### **Heuristics for TSPs**

# %% [markdown]
# ![](2023-11-11-16-13-20.png)

# %% [markdown]
# ![](2023-11-11-16-13-37.png)

# %% [markdown]
# ![](2023-11-11-16-14-13.png)

# %% [markdown]
# ![](2023-11-11-16-14-37.png)

# %% [markdown]
# ![](2023-11-11-16-14-54.png)

# %% [markdown]
# ![](2023-11-11-16-15-14.png)

# %% [markdown]
# ![](2023-11-11-16-15-38.png)

# %% [markdown]
# ![](2023-11-11-16-16-21.png)

# %% [markdown]
# ![](2023-11-11-16-16-47.png)

# %% [markdown]
# ![](2023-11-11-16-17-40.png)

# %% [markdown]
# ![](2023-11-11-16-17-52.png)

# %% [markdown]
# ![](2023-11-11-16-18-43.png)

# %% [markdown]
# ![](2023-11-11-16-18-59.png)

# %% [markdown]
# ![](2023-11-11-16-19-24.png)

# %% [markdown]
# ![](2023-11-11-16-19-39.png)

# %% [markdown]
# ## **Approximation Scheme and the Knapsack Problem**

# %% [markdown]
# ### **Full Polynomial Time Approximation Scheme and Knapsack**

# %% [markdown]
# ![](2023-11-11-21-25-02.png)

# %% [markdown]
# ![](2023-11-11-21-25-41.png)

# %% [markdown]
# ![](2023-11-05-21-24-55.png)

# %% [markdown]
# ![](2023-11-11-21-27-39.png)

# %% [markdown]
# ![](2023-11-11-21-30-20.png)

# %% [markdown]
# ![](2023-11-11-21-30-51.png)

# %% [markdown]
# ![](2023-11-11-21-36-54.png)

# %% [markdown]
# ![](2023-11-11-21-37-21.png)

# %% [markdown]
# ![](2023-11-11-21-38-02.png)

# %% [markdown]
# ![](2023-11-11-21-38-35.png)

# %% [markdown]
# ![](2023-11-11-21-40-41.png)

# %% [markdown]
# ![](2023-11-11-21-42-40.png)

# %% [markdown]
# ![](2023-11-11-21-43-18.png)

# %% [markdown]
# ![](2023-11-11-21-44-02.png)

# %% [markdown]
# ![](2023-11-11-21-44-48.png)

# %% [markdown]
# ![](2023-11-11-21-45-26.png)

# %% [markdown]
# ![](2023-11-11-21-46-03.png)

# %% [markdown]
# ![](2023-11-11-21-46-21.png)

# %% [markdown]
# ![](2023-11-11-21-51-24.png)

# %% [markdown]
# ![](2023-11-11-21-52-46.png)

# %% [markdown]
# ![](2023-11-11-22-04-22.png)

# %% [markdown]
# ![](2023-11-11-22-05-14.png)

# %% [markdown]
# ![](2023-11-11-22-05-58.png)

# %% [markdown]
# ![](2023-11-11-22-06-52.png)

# %% [markdown]
# ![](2023-11-11-22-08-00.png)

# %% [markdown]
# ![](2023-11-11-22-08-22.png)

# %% [markdown]
# ![](2023-11-05-21-26-07.png)

# %% [markdown]
# ![](2023-11-05-21-28-20.png)

# %% [markdown]
# ![](2023-11-05-21-30-52.png)

# %% [markdown]
# ![](2023-11-05-21-31-18.png)

# %% [markdown]
# ![](2023-11-05-21-31-39.png)

# %% [markdown]
# ![](2023-11-05-21-35-50.png)

# %% [markdown]
# ![](2023-11-05-21-37-00.png)

# %% [markdown]
# ![](2023-11-05-21-38-00.png)

# %% [markdown]
# ![](2023-11-05-21-38-45.png)

# %% [markdown]
# ![](2023-11-05-21-42-23.png)

# %% [markdown]
# ![](2023-11-05-21-45-19.png)

# %% [markdown]
# ![](2023-11-05-21-48-50.png)

# %% [markdown]
# ![](2023-11-05-21-49-53.png)

# %% [markdown]
# ![](2023-11-05-21-52-08.png)

# %% [markdown]
# ![](2023-11-05-21-52-43.png)

# %% [markdown]
# ![](2023-11-05-21-53-09.png)

# %% [markdown]
# ![](2023-11-05-21-53-36.png)

# %% [markdown]
# ![](2023-11-05-21-54-49.png)

# %% [markdown]
# ![](2023-11-05-21-56-10.png)

# %% [markdown]
# ![](2023-11-05-22-00-27.png)

# %% [markdown]
# ### **Alternative Greedy Algorithm:**

# %% [markdown]
# ![](2023-11-05-22-02-01.png)

# %% [markdown]
# ![](2023-11-05-22-02-30.png)

# %% [markdown]
# ![](2023-11-05-22-02-57.png)

# %% [markdown]
# ![](2023-11-05-22-04-39.png)

# %% [markdown]
# ![](2023-11-05-22-05-05.png)

# %% [markdown]
# ![](2023-11-05-22-05-31.png)

# %% [markdown]
# ![](2023-11-05-22-05-50.png)

# %% [markdown]
# ![](2023-11-05-22-06-38.png)

# %% [markdown]
# ![](2023-11-05-22-07-55.png)

# %% [markdown]
# ![](2023-11-05-22-08-15.png)

# %% [markdown]
# ![](2023-11-05-22-08-29.png)

# %% [markdown]
# ![](2023-11-05-22-11-37.png)

# %% [markdown]
# ![](2023-11-05-22-11-53.png)

# %% [markdown]
# ## **Maximum Satisfiability Problem**

# %% [markdown]
# ![](2023-11-06-06-50-36.png)

# %% [markdown]
# ![](2023-11-06-06-51-09.png)

# %% [markdown]
# ![](2023-11-06-06-52-16.png)

# %% [markdown]
# **The approximation method:**

# %% [markdown]
# ![](2023-11-06-06-54-04.png)

# %% [markdown]
# ![](2023-11-06-06-54-49.png)

# %% [markdown]
# ![](2023-11-06-06-55-44.png)

# %% [markdown]
# ![](2023-11-06-06-56-19.png)

# %% [markdown]
# ![](2023-11-06-06-57-18.png)

# %% [markdown]
# ![](2023-11-06-06-58-12.png)

# %% [markdown]
# ![](2023-11-06-06-59-15.png)

# %% [markdown]
# ![](2023-11-06-07-00-57.png)

# %% [markdown]
# ![](2023-11-06-07-02-18.png)

# %% [markdown]
# ![](2023-11-06-07-02-39.png)

# %% [markdown]
# ![](2023-11-06-07-03-04.png)

# %% [markdown]
# ![](2023-11-06-07-04-24.png)

# %% [markdown]
# ![](2023-11-06-07-05-04.png)

# %% [markdown]
# ![](2023-11-06-07-05-28.png)

# %% [markdown]
# ![](2023-11-06-07-06-35.png)

# %% [markdown]
# ![](2023-11-06-07-07-11.png)

# %% [markdown]
# ![](2023-11-06-07-07-48.png)

# %% [markdown]
# ![](2023-11-06-07-12-47.png)

# %% [markdown]
# ![](2023-11-06-07-13-32.png)

# %% [markdown]
# ![](2023-11-06-07-14-39.png)

# %% [markdown]
# ![](2023-11-06-07-16-42.png)

# %% [markdown]
# ![](2023-11-06-07-17-46.png)

# %% [markdown]
# ![](2023-11-06-07-18-22.png)

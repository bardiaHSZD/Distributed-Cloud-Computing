# %% [markdown]
# # **Approximation Algorithms**

# %% [markdown]
# ## **Introduction to Approximation Algorithms**

# %% [markdown]
# ![](2023-11-05-14-41-08.png)

# %% [markdown]
# ![](2023-11-05-14-42-20.png)

# %% [markdown]
# ## **Jobshop Scheduling and Algorithm Design**

# %% [markdown]
# ![](2023-11-05-14-47-03.png)

# %% [markdown]
# **The load of each processor os defomed as:**

# %% [markdown]
# ![](2023-11-05-14-49-19.png)

# %% [markdown]
# ![](2023-11-05-14-50-15.png)

# %% [markdown]
# ![](2023-11-05-14-50-36.png)

# %% [markdown]
# **Makespan defines the total time required to finish all the tasks, a.k.a. the maximum of time required per processor.**

# %% [markdown]
# ![](2023-11-05-14-51-19.png)

# %% [markdown]
# ![](2023-11-05-14-54-33.png)

# %% [markdown]
# ![](2023-11-05-14-58-40.png)

# %% [markdown]
# ### The Greedy Solution

# %% [markdown]
# ![](2023-11-05-14-59-59.png)

# %% [markdown]
# ![](2023-11-05-15-03-01.png)

# %% [markdown]
# ![](2023-11-05-15-04-45.png)

# %% [markdown]
# ![](2023-11-05-15-06-30.png)

# %% [markdown]
# **Take a snap shot**

# %% [markdown]
# ![](2023-11-05-15-09-20.png)

# %% [markdown]
# ![](2023-11-05-15-11-03.png)

# %% [markdown]
# ![](2023-11-05-15-12-48.png)

# %% [markdown]
# ![](2023-11-05-15-14-19.png)

# %% [markdown]
# ### Alternative Method:

# %% [markdown]
# ![](2023-11-05-15-16-08.png)

# %% [markdown]
# ![](2023-11-05-15-17-05.png)

# %% [markdown]
# ![](2023-11-05-15-20-03.png)

# %% [markdown]
# ## **Vertex Cover**

# %% [markdown]
# ![](2023-11-05-21-20-02.png)

# %% [markdown]
# ![](2023-11-05-21-24-55.png)

# %% [markdown]
# ![](2023-11-05-21-26-07.png)

# %% [markdown]
# ![](2023-11-05-21-28-20.png)

# %% [markdown]
# ![](2023-11-05-21-30-52.png)

# %% [markdown]
# ![](2023-11-05-21-31-18.png)

# %% [markdown]
# ![](2023-11-05-21-31-39.png)

# %% [markdown]
# ![](2023-11-05-21-35-50.png)

# %% [markdown]
# ![](2023-11-05-21-37-00.png)

# %% [markdown]
# ![](2023-11-05-21-38-00.png)

# %% [markdown]
# ![](2023-11-05-21-38-45.png)

# %% [markdown]
# ![](2023-11-05-21-42-23.png)

# %% [markdown]
# ![](2023-11-05-21-45-19.png)

# %% [markdown]
# ![](2023-11-05-21-48-50.png)

# %% [markdown]
# ![](2023-11-05-21-49-53.png)

# %% [markdown]
# ![](2023-11-05-21-52-08.png)

# %% [markdown]
# ![](2023-11-05-21-52-43.png)

# %% [markdown]
# ![](2023-11-05-21-53-09.png)

# %% [markdown]
# ![](2023-11-05-21-53-36.png)

# %% [markdown]
# ![](2023-11-05-21-54-49.png)

# %% [markdown]
# ![](2023-11-05-21-56-10.png)

# %% [markdown]
# ![](2023-11-05-22-00-27.png)

# %% [markdown]
# ### **Alternative Greedy Algorithm:**

# %% [markdown]
# ![](2023-11-05-22-02-01.png)

# %% [markdown]
# ![](2023-11-05-22-02-30.png)

# %% [markdown]
# ![](2023-11-05-22-02-57.png)

# %% [markdown]
# ![](2023-11-05-22-04-39.png)

# %% [markdown]
# ![](2023-11-05-22-05-05.png)

# %% [markdown]
# ![](2023-11-05-22-05-31.png)

# %% [markdown]
# ![](2023-11-05-22-05-50.png)

# %% [markdown]
# ![](2023-11-05-22-06-38.png)

# %% [markdown]
# ![](2023-11-05-22-07-55.png)

# %% [markdown]
# ![](2023-11-05-22-08-15.png)

# %% [markdown]
# ![](2023-11-05-22-08-29.png)

# %% [markdown]
# ![](2023-11-05-22-11-37.png)

# %% [markdown]
# ![](2023-11-05-22-11-53.png)

# %% [markdown]
# ## **Maximum Satisfiability Problem**

# %% [markdown]
# ![](2023-11-06-06-50-36.png)

# %% [markdown]
# ![](2023-11-06-06-51-09.png)

# %% [markdown]
# ![](2023-11-06-06-52-16.png)

# %% [markdown]
# **The approximation method:**

# %% [markdown]
# ![](2023-11-06-06-54-04.png)

# %% [markdown]
# ![](2023-11-06-06-54-49.png)

# %% [markdown]
# ![](2023-11-06-06-55-44.png)

# %% [markdown]
# ![](2023-11-06-06-56-19.png)

# %% [markdown]
# ![](2023-11-06-06-57-18.png)

# %% [markdown]
# ![](2023-11-06-06-58-12.png)

# %% [markdown]
# ![](2023-11-06-06-59-15.png)

# %% [markdown]
# ![](2023-11-06-07-00-57.png)

# %% [markdown]
# ![](2023-11-06-07-02-18.png)

# %% [markdown]
# ![](2023-11-06-07-02-39.png)

# %% [markdown]
# ![](2023-11-06-07-03-04.png)

# %% [markdown]
# ![](2023-11-06-07-04-24.png)

# %% [markdown]
# ![](2023-11-06-07-05-04.png)

# %% [markdown]
# ![](2023-11-06-07-05-28.png)

# %% [markdown]
# ![](2023-11-06-07-06-35.png)

# %% [markdown]
# ![](2023-11-06-07-07-11.png)

# %% [markdown]
# ![](2023-11-06-07-07-48.png)

# %% [markdown]
# ![](2023-11-06-07-12-47.png)

# %% [markdown]
# ![](2023-11-06-07-13-32.png)

# %% [markdown]
# ![](2023-11-06-07-14-39.png)

# %% [markdown]
# ![](2023-11-06-07-16-42.png)

# %% [markdown]
# ![](2023-11-06-07-17-46.png)

# %% [markdown]
# ![](2023-11-06-07-18-22.png)

# %% [markdown]
# # **Integer Linear Programming**

# %% [markdown]
# ## **What is an Integer Linear Program?**

# %% [markdown]
# ![](2023-11-02-19-26-05.png)

# %% [markdown]
# ![](2023-11-02-19-27-51.png)

# %% [markdown]
# ![](2023-11-02-19-31-19.png)

# %% [markdown]
# ![](2023-11-02-19-32-53.png)

# %% [markdown]
# ![](2023-11-02-19-33-54.png)

# %% [markdown]
# ![](2023-11-02-19-35-34.png)

# %% [markdown]
# ![](2023-11-02-19-36-35.png)

# %% [markdown]
# ![](2023-11-02-19-37-49.png)

# %% [markdown]
# ![](2023-11-02-19-38-39.png)

# %% [markdown]
# ![](2023-11-02-19-39-40.png)

# %% [markdown]
# ![](2023-11-02-19-40-56.png)

# %% [markdown]
# ![](2023-11-02-19-42-02.png)

# %% [markdown]
# ## **NP Hardness of Integer Linear Programming**

# %% [markdown]
# ![](2023-11-02-19-49-09.png)

# %% [markdown]
# ![](2023-11-02-19-49-47.png)

# %% [markdown]
# **Once it is shown that it is NP-Hard, we would like to show it is NP-Complete:**

# %% [markdown]
# ![](2023-11-02-19-51-11.png)

# %% [markdown]
# ![](2023-11-02-19-52-12.png)

# %% [markdown]
# ![](2023-11-02-19-53-00.png)

# %% [markdown]
# ![](2023-11-02-19-53-22.png)

# %% [markdown]
# ![](2023-11-02-19-54-08.png)

# %% [markdown]
# ![](2023-11-02-19-54-43.png)

# %% [markdown]
# ![](2023-11-02-19-56-36.png)

# %% [markdown]
# ![](2023-11-02-19-56-55.png)

# %% [markdown]
# ![](2023-11-02-19-57-37.png)

# %% [markdown]
# ![](2023-11-02-19-58-16.png)

# %% [markdown]
# ![](2023-11-02-19-58-35.png)

# %% [markdown]
# ![](2023-11-02-19-58-46.png)

# %% [markdown]
# ![](2023-11-02-19-59-12.png)

# %% [markdown]
# ![](2023-11-02-20-00-39.png)

# %% [markdown]
# ## **Vertex Cover as an Integer Linear Program**

# %% [markdown]
# ![](2023-11-04-17-32-42.png)

# %% [markdown]
# ![](2023-11-04-17-33-07.png)

# %% [markdown]
# ![](2023-11-04-17-33-49.png)

# %% [markdown]
# ![](2023-11-04-17-34-42.png)

# %% [markdown]
# ![](2023-11-04-17-35-11.png)

# %% [markdown]
# ![](2023-11-04-17-37-55.png)

# %% [markdown]
# ![](2023-11-04-17-38-24.png)

# %% [markdown]
# ![](2023-11-04-17-40-28.png)

# %% [markdown]
# ![](2023-11-04-17-40-59.png)

# %% [markdown]
# ## **Linear Programming Approximations to Vertex Cover**

# %% [markdown]
# ![](2023-11-04-18-34-44.png)

# %% [markdown]
# ![](2023-11-04-18-55-59.png)

# %% [markdown]
# ![](2023-11-04-18-56-58.png)

# %% [markdown]
# ![](2023-11-04-19-01-53.png)

# %% [markdown]
# **Note: Typo in the text above; the max should min.**

# %% [markdown]
# ![](2023-11-04-19-03-36.png)

# %% [markdown]
# ![](2023-11-04-19-15-59.png)

# %% [markdown]
# ![](2023-11-04-19-17-49.png)

# %% [markdown]
# ![](2023-11-04-19-19-02.png)

# %% [markdown]
# ![](2023-11-04-19-19-43.png)

# %% [markdown]
# ![](2023-11-04-19-20-45.png)

# %% [markdown]
# ![](2023-11-04-19-21-14.png)

# %% [markdown]
# ![](2023-11-04-19-21-51.png)

# %% [markdown]
# ![](2023-11-04-19-35-01.png)

# %% [markdown]
# ## **Branch and Bound Algorithm for Solving Integer Linear Programs**

# %% [markdown]
# ![](2023-11-05-07-48-00.png)

# %% [markdown]
# ![](2023-11-05-07-50-11.png)

# %% [markdown]
# ![](2023-11-05-07-50-39.png)

# %% [markdown]
# ![](2023-11-05-07-51-48.png)

# %% [markdown]
# ![](2023-11-05-07-53-22.png)

# %% [markdown]
# **Now let's explain the branch-and-bound method:**

# %% [markdown]
# ![](2023-11-05-07-55-28.png)

# %% [markdown]
# ![](2023-11-05-07-56-37.png)

# %% [markdown]
# ![](2023-11-05-07-56-52.png)

# %% [markdown]
# ![](2023-11-05-07-57-32.png)

# %% [markdown]
# ![](2023-11-05-07-57-46.png)

# %% [markdown]
# **Then bring the solutions together, and**

# %% [markdown]
# ![](2023-11-05-07-59-09.png)

# %% [markdown]
# **You would choose that branhc solution as the best answer.**

# %% [markdown]
# ![](2023-11-05-08-00-37.png)

# %% [markdown]
# ![](2023-11-05-08-01-36.png)

# %% [markdown]
# **The resulting LP programs have more contraints:"**

# %% [markdown]
# ![](2023-11-05-08-03-39.png)

# %% [markdown]
# **If one leaf is infeasible:**

# %% [markdown]
# ![](2023-11-05-08-06-09.png)

# %% [markdown]
# ![](2023-11-05-08-07-27.png)

# %% [markdown]
# ![](2023-11-05-08-08-07.png)

# %% [markdown]
# **One trick to help the program run faster is to keep track of the best solution so far, and when we get to a branch with objective function less than that we would not continue that branhc:**

# %% [markdown]
# ![](2023-11-05-08-11-40.png)

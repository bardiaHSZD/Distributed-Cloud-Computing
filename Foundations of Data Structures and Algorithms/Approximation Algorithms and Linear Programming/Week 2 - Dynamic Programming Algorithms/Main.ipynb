# %% [markdown]
# # **Integer Linear Programming**

# %% [markdown]
# ## **What is an Integer Linear Program?**

# %% [markdown]
# ![](2023-10-25-12-16-17.png)

# %% [markdown]
# ## **NP Hardness of Integer Linear Programming**

# %% [markdown]
# ![](2023-10-25-14-17-54.png)

# %% [markdown]
# ![](2023-10-25-14-20-18.png)

# %% [markdown]
# ![](2023-10-25-14-22-33.png)

# %% [markdown]
# ![](2023-10-25-14-27-52.png)

# %% [markdown]
# ![](2023-10-25-14-30-26.png)

# %% [markdown]
# ![](2023-10-25-14-32-13.png)

# %% [markdown]
# ![](2023-10-25-14-36-07.png)

# %% [markdown]
# ![](2023-10-25-14-44-13.png)

# %% [markdown]
# ## **Vertex Cover as an Integer Linear Program**

# %% [markdown]
# ![](2023-10-25-14-46-16.png)

# %% [markdown]
# ![](2023-10-25-14-47-41.png)

# %% [markdown]
# ![](2023-10-25-14-48-03.png)

# %% [markdown]
# ![](2023-10-25-14-48-44.png)

# %% [markdown]
# ## **Linear Programming Approximations to Vertex Cover**

# %% [markdown]
# ## **Branch and Bound Algorithm for Solving Integer Linear Programs**

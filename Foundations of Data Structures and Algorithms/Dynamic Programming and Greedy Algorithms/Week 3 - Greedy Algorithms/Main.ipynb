# %% [markdown]
# # **Greedy Agorithms**

# %% [markdown]
# ## **Introduction to Greedy Algorithms**

# %% [markdown]
# ![](2023-10-25-16-41-23.png)

# %% [markdown]
# ![](2023-10-25-16-42-09.png)

# %% [markdown]
# ![](2023-10-25-16-42-58.png)

# %% [markdown]
# ![](2023-10-25-16-43-36.png)

# %% [markdown]
# ![](2023-10-25-16-44-14.png)

# %% [markdown]
# ![](2023-10-25-16-44-51.png)

# %% [markdown]
# ![](2023-10-25-16-46-23.png)

# %% [markdown]
# ![](2023-10-25-16-48-26.png)

# %% [markdown]
# ![](2023-10-25-16-49-30.png)

# %% [markdown]
# ![](2023-10-25-16-52-35.png)

# %% [markdown]
# ![](2023-10-25-16-54-16.png)

# %% [markdown]
# ![](2023-10-25-16-57-19.png)

# %% [markdown]
# ## **Greedy Interval Scheduling**

# %% [markdown]
# ![](2023-10-25-20-28-27.png)

# %% [markdown]
# ![](2023-10-25-20-33-17.png)

# %% [markdown]
# ![](2023-10-25-20-41-03.png)

# %% [markdown]
# ![](2023-10-25-20-44-31.png)

# %% [markdown]
# ![](2023-10-25-20-45-55.png)

# %% [markdown]
# ![](2023-10-25-20-54-56.png)

# %% [markdown]
# ## **Prefix Codes and Optimal Prefix Codes**

# %% [markdown]
# ![](2023-10-25-22-14-53.png)

# %% [markdown]
# ![](2023-10-25-22-17-18.png)

# %% [markdown]
# ![](2023-10-25-22-18-46.png)

# %% [markdown]
# ![](2023-10-25-22-21-39.png)

# %% [markdown]
# ![](2023-10-25-22-23-11.png)

# %% [markdown]
# ![](2023-10-25-22-24-03.png)

# %% [markdown]
# ![](2023-10-25-22-26-51.png)

# %% [markdown]
# ![](2023-10-25-22-28-19.png)

# %% [markdown]
# ![](2023-10-25-22-28-51.png)

# %% [markdown]
# ![](2023-10-25-22-29-15.png)

# %% [markdown]
# ![](2023-10-25-22-30-14.png)

# %% [markdown]
# ![](2023-10-25-22-37-57.png)

# %% [markdown]
# ![](2023-10-25-22-39-14.png)

# %% [markdown]
# ![](2023-10-25-22-42-04.png)

# %% [markdown]
# ![](2023-10-25-22-44-23.png)

# %% [markdown]
# ![](2023-10-25-22-57-52.png)

# %% [markdown]
# ![](2023-10-25-23-01-02.png)

# %% [markdown]
# ![](2023-10-25-23-11-54.png)

# %% [markdown]
# ![](2023-10-25-23-14-01.png)

# %% [markdown]
# ![](2023-10-25-23-27-40.png)

# %% [markdown]
# ![](2023-10-25-23-28-08.png)

# %% [markdown]
# ![](2023-10-25-23-28-56.png)

# %% [markdown]
# ![](2023-10-25-23-29-30.png)

# %% [markdown]
# ![](2023-10-25-23-29-54.png)

# %% [markdown]
# ![](2023-10-25-23-30-51.png)

# %% [markdown]
# ![](2023-10-25-23-31-30.png)

# %% [markdown]
# ![](2023-10-25-23-31-47.png)

# %% [markdown]
# ![](2023-10-25-23-32-11.png)

# %% [markdown]
# ![](2023-10-25-23-33-08.png)

# %% [markdown]
# ![](2023-10-25-23-33-30.png)

# %% [markdown]
# ![](2023-10-25-23-34-20.png)

# %% [markdown]
# ![](2023-10-25-23-34-50.png)

# %% [markdown]
# ![](2023-10-25-23-35-22.png)

# %% [markdown]
# ![](2023-10-25-23-35-38.png)

# %% [markdown]
# ![](2023-10-25-23-36-02.png)

# %% [markdown]
# ### **Optimal Prefix Codes**

# %% [markdown]
# ![](2023-10-26-07-33-46.png)

# %% [markdown]
# ![](2023-10-26-07-51-52.png)

# %% [markdown]
# ![](2023-10-26-07-52-18.png)

# %% [markdown]
# ![](2023-10-26-07-53-02.png)

# %% [markdown]
# **At every step, give it a frequency of the sum of the frequencies of characters your are combining. And the final frequncy would be calculated as following:**

# %% [markdown]
# ![](2023-10-26-07-55-46.png)

# %% [markdown]
# **And the coding becomes:**

# %% [markdown]
# ![](2023-10-26-07-57-13.png)

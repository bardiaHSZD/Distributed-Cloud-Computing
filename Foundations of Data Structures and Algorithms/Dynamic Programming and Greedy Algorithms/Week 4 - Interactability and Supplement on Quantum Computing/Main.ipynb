# %% [markdown]
# # **Interactability and Supplement on Quantum Computing**

# %% [markdown]
# ## **Decision Problems and Languages**

# %% [markdown]
# ![](2023-10-28-22-05-04.png)

# %% [markdown]
# ![](2023-10-28-22-07-30.png)

# %% [markdown]
# ![](2023-10-28-22-09-52.png)

# %% [markdown]
# ![](2023-10-28-22-16-43.png)

# %% [markdown]
# ![](2023-10-28-22-24-45.png)

# %% [markdown]
# ![](2023-10-28-22-28-38.png)

# %% [markdown]
# ![](2023-10-28-22-30-57.png)

# %% [markdown]
# ![](2023-10-28-22-41-02.png)

# %% [markdown]
# ![](2023-10-28-22-43-25.png)

# %% [markdown]
# ![](2023-10-28-22-48-37.png)

# %% [markdown]
# ![](2023-10-28-22-50-07.png)

# %% [markdown]
# ![](2023-10-28-22-55-28.png)

# %% [markdown]
# ![](2023-10-28-22-57-21.png)

# %% [markdown]
# ![](2023-10-28-22-59-30.png)

# %% [markdown]
# ![](2023-10-28-23-01-10.png)

# %% [markdown]
# ![](2023-10-28-23-29-39.png)

# %% [markdown]
# ![](2023-10-28-23-34-59.png)

# %% [markdown]
# ## **Polynomial Time Problems**

# %% [markdown]
# ![](2023-10-29-07-28-51.png)

# %% [markdown]
# ![](2023-10-29-07-30-13.png)

# %% [markdown]
# ![](2023-10-29-07-33-15.png)

# %% [markdown]
# ![](2023-10-29-07-35-14.png)

# %% [markdown]
# ![](2023-10-29-07-37-12.png)

# %% [markdown]
# ![](2023-10-29-07-39-00.png)

# %% [markdown]
# ![](2023-10-29-07-40-07.png)

# %% [markdown]
# ![](2023-10-29-07-41-13.png)

# %% [markdown]
# ![](2023-10-29-07-42-25.png)

# %% [markdown]
# ![](2023-10-29-07-43-26.png)

# %% [markdown]
# ![](2023-10-29-07-44-09.png)

# %% [markdown]
# ![](2023-10-29-07-45-24.png)

# %% [markdown]
# ![](2023-10-29-07-47-08.png)

# %% [markdown]
# ![](2023-10-29-07-48-26.png)

# %% [markdown]
# ## **NP Definition and NP Completeness**

# %% [markdown]
# ![](2023-10-29-08-01-25.png)

# %% [markdown]
# ![](2023-10-29-08-03-19.png)

# %% [markdown]
# ![](2023-10-29-08-04-16.png)

# %% [markdown]
# ![](2023-10-29-08-05-21.png)

# %% [markdown]
# ![](2023-10-29-08-06-34.png)

# %% [markdown]
# ![](2023-10-29-08-08-14.png)

# %% [markdown]
# ![](2023-10-29-08-09-23.png)

# %% [markdown]
# ![](2023-10-29-08-09-37.png)

# %% [markdown]
# ![](2023-10-29-08-10-10.png)

# %% [markdown]
# ![](2023-10-29-08-10-41.png)

# %% [markdown]
# ![](2023-10-29-08-11-51.png)

# %% [markdown]
# ![](2023-10-29-08-13-10.png)

# %% [markdown]
# ![](2023-10-29-08-14-48.png)

# %% [markdown]
# ![](2023-10-29-08-16-05.png)

# %% [markdown]
# ![](2023-10-29-08-17-20.png)

# %% [markdown]
# ![](2023-10-29-08-21-08.png)

# %% [markdown]
# ![](2023-10-29-10-51-43.png)

# %% [markdown]
# ![](2023-10-29-10-52-36.png)

# %% [markdown]
# ![](2023-10-29-10-53-24.png)

# %% [markdown]
# ![](2023-10-29-10-59-14.png)

# %% [markdown]
# ![](2023-10-29-11-02-12.png)

# %% [markdown]
# ![](2023-10-29-11-08-01.png)

# %% [markdown]
# ![](2023-10-29-11-08-50.png)

# %% [markdown]
# ![](2023-10-29-11-09-30.png)

# %% [markdown]
# ![](2023-10-29-11-12-35.png)

# %% [markdown]
# ![](2023-10-29-11-13-34.png)

# %% [markdown]
# ![](2023-10-29-11-15-44.png)

# %% [markdown]
# ![](2023-10-29-11-16-55.png)

# %% [markdown]
# ![](2023-10-29-11-19-00.png)

# %% [markdown]
# ![](2023-10-29-11-21-08.png)

# %% [markdown]
# ![](2023-10-29-11-22-19.png)

# %% [markdown]
# **Note: Each clause has three literals and if we want to have only one literal such as x1 we should have: Cj:(x1 V x1 V x1)**

# %% [markdown]
# ![](2023-10-29-11-30-05.png)

# %% [markdown]
# ![](2023-10-29-11-31-32.png)

# %% [markdown]
# ![](2023-10-29-11-32-53.png)

# %% [markdown]
# ![](2023-10-29-11-34-04.png)

# %% [markdown]
# ![](2023-10-29-11-34-47.png)

# %% [markdown]
# ![](2023-10-29-11-35-20.png)

# %% [markdown]
# ![](2023-10-29-11-36-28.png)

# %% [markdown]
# ![](2023-10-29-11-45-34.png)

# %% [markdown]
# ![](2023-10-29-11-46-18.png)

# %% [markdown]
# **We never connect a node to its negation or to the nodes in same clause.**

# %% [markdown]
# ![](2023-10-29-11-48-56.png)

# %% [markdown]
# ![](2023-10-29-11-49-14.png)

# %% [markdown]
# ![](2023-10-29-11-50-05.png)

# %% [markdown]
# ![](2023-10-29-11-50-26.png)

# %% [markdown]
# ![](2023-10-29-11-51-03.png)

# %% [markdown]
# ![](2023-10-29-11-51-28.png)

# %% [markdown]
# ![](2023-10-29-11-53-35.png)

# %% [markdown]
# **and if**

# %% [markdown]
# ![](2023-10-29-11-54-33.png)

# %% [markdown]
# ## **NP Complete Problems**

# %% [markdown]
# ### **3-CNF-SAT**

# %% [markdown]
# ![](2023-10-29-14-18-04.png)

# %% [markdown]
# ### **2-CNF-SAT**

# %% [markdown]
# ![](2023-10-29-14-19-34.png)

# %% [markdown]
# ![](2023-10-29-14-21-55.png)

# %% [markdown]
# ### **HORN-SAT**

# %% [markdown]
# ![](2023-10-29-14-25-07.png)

# %% [markdown]
# ![](2023-10-29-14-26-10.png)

# %% [markdown]
# ![](2023-10-29-14-29-07.png)

# %% [markdown]
# ### **MAX-SAT**

# %% [markdown]
# ![](2023-10-29-14-30-49.png)

# %% [markdown]
# ![](2023-10-29-14-31-14.png)

# %% [markdown]
# ![](2023-10-29-14-34-34.png)

# %% [markdown]
# ### **Graphs**

# %% [markdown]
# ![](2023-10-29-14-35-22.png)

# %% [markdown]
# ### **Vertex Cover**

# %% [markdown]
# ![](2023-10-29-14-37-10.png)

# %% [markdown]
# ![](2023-10-29-14-37-49.png)

# %% [markdown]
# ![](2023-10-29-14-38-07.png)

# %% [markdown]
# ![](2023-10-29-14-39-24.png)

# %% [markdown]
# ![](2023-10-29-14-44-30.png)

# %% [markdown]
# ![](2023-10-29-14-45-11.png)

# %% [markdown]
# ![](2023-10-29-14-45-44.png)

# %% [markdown]
# ![](2023-10-29-14-46-20.png)

# %% [markdown]
# ![](2023-10-29-14-46-49.png)

# %% [markdown]
# #### **Proof**

# %% [markdown]
# ![](2023-10-29-14-48-51.png)

# %% [markdown]
# ![](2023-10-29-14-50-12.png)

# %% [markdown]
# ![](2023-10-29-14-50-46.png)

# %% [markdown]
# ![](2023-10-29-14-50-58.png)

# %% [markdown]
# ![](2023-10-29-14-52-06.png)

# %% [markdown]
# ![](2023-10-29-14-52-30.png)

# %% [markdown]
# ![](2023-10-29-14-52-43.png)

# %% [markdown]
# ![](2023-10-29-14-53-47.png)

# %% [markdown]
# ![](2023-10-29-14-55-00.png)

# %% [markdown]
# ![](2023-10-29-14-55-55.png)

# %% [markdown]
# ### **0-1 Integer Linear Programming**

# %% [markdown]
# ![](2023-10-29-14-57-49.png)

# %% [markdown]
# ![](2023-10-29-15-00-27.png)

# %% [markdown]
# ![](2023-10-29-15-01-58.png)

# %% [markdown]
# ![](2023-10-29-15-03-23.png)

# %% [markdown]
# ### **Knapsack Problem**

# %% [markdown]
# ![](2023-10-29-15-05-30.png)

# %% [markdown]
# ![](2023-10-29-15-06-33.png)

# %% [markdown]
# ### **Traveling Sales Person**

# %% [markdown]
# ![](2023-10-29-15-07-24.png)

# %% [markdown]
# ![](2023-10-29-15-07-49.png)

# %% [markdown]
# ## **Supplementary Lectures: Quantum Computing**

# %% [markdown]
# ### **Quantum and Physics**

# %% [markdown]
# ![](2023-10-29-20-13-33.png)

# %% [markdown]
# ![](2023-10-29-20-18-11.png)

# %% [markdown]
# ![](2023-10-29-20-20-24.png)

# %% [markdown]
# ![](2023-10-29-20-22-35.png)

# %% [markdown]
# ![](2023-10-29-20-23-19.png)

# %% [markdown]
# ![](2023-10-29-20-23-54.png)

# %% [markdown]
# ![](2023-10-29-20-24-38.png)

# %% [markdown]
# ![](2023-10-29-20-28-44.png)

# %% [markdown]
# ![](2023-10-29-20-29-23.png)

# %% [markdown]
# ![](2023-10-29-20-31-09.png)

# %% [markdown]
# ![](2023-10-29-20-33-48.png)

# %% [markdown]
# ![](2023-10-29-20-34-00.png)

# %% [markdown]
# ![](2023-10-29-20-36-53.png)

# %% [markdown]
# ![](2023-10-29-20-38-12.png)

# %% [markdown]
# ![](2023-10-29-20-41-01.png)

# %% [markdown]
# ![](2023-10-29-20-44-42.png)

# %% [markdown]
# ![](2023-10-29-20-46-15.png)

# %% [markdown]
# ![](2023-10-29-20-56-25.png)

# %% [markdown]
# ![](2023-10-29-20-58-49.png)

# %% [markdown]
# ![](2023-10-29-21-09-33.png)

# %% [markdown]
# ![](2023-10-29-21-11-25.png)

# %% [markdown]
# ![](2023-10-29-21-25-29.png)

# %% [markdown]
# ![](2023-10-29-21-30-09.png)

# %% [markdown]
# ![](2023-10-29-21-30-58.png)

# %% [markdown]
# ![](2023-10-29-21-35-44.png)

# %% [markdown]
# ![](2023-10-29-21-38-16.png)

# %% [markdown]
# ### **Qubits and Operations**

# %% [markdown]
# ![](2023-10-29-22-14-10.png)

# %% [markdown]
# ![](2023-10-29-22-15-42.png)

# %% [markdown]
# ![](2023-10-29-22-19-29.png)

# %% [markdown]
# ![](2023-10-29-22-20-45.png)

# %% [markdown]
# ![](2023-10-29-22-21-28.png)

# %% [markdown]
# ![](2023-10-29-22-24-48.png)

# %% [markdown]
# ![](2023-10-29-22-26-20.png)

# %% [markdown]
# ![](2023-10-29-22-27-38.png)

# %% [markdown]
# ![](2023-10-29-22-33-20.png)

# %% [markdown]
# ![](2023-10-29-22-35-37.png)

# %% [markdown]
# ![](2023-10-29-22-39-10.png)

# %% [markdown]
# ![](2023-10-29-22-41-13.png)

# %% [markdown]
# ![](2023-10-29-22-42-25.png)

# %% [markdown]
# ![](2023-10-29-22-49-48.png)

# %% [markdown]
# ![](2023-10-29-22-50-24.png)

# %% [markdown]
# ![](2023-10-29-22-50-56.png)

# %% [markdown]
# ![](2023-10-29-22-52-17.png)

# %% [markdown]
# ![](2023-10-29-22-52-54.png)

# %% [markdown]
# ![](2023-10-29-22-54-48.png)

# %% [markdown]
# ![](2023-10-29-22-55-06.png)

# %% [markdown]
# ![](2023-10-29-22-56-27.png)

# %% [markdown]
# ![](2023-10-29-23-03-09.png)

# %% [markdown]
# ![](2023-10-29-23-08-11.png)

# %% [markdown]
# ![](2023-10-29-23-09-00.png)

# %% [markdown]
# ![](2023-10-29-23-15-00.png)

# %% [markdown]
# ![](2023-10-29-23-21-02.png)

# %% [markdown]
# ![](2023-10-29-23-29-57.png)

# %% [markdown]
# ![](2023-10-29-23-37-10.png)

# %% [markdown]
# ![](2023-10-29-23-40-37.png)

# %% [markdown]
# ![](2023-10-30-07-26-59.png)

# %% [markdown]
# ![](2023-10-30-07-27-50.png)

# %% [markdown]
# ![](2023-10-30-07-28-32.png)

# %% [markdown]
# ![](2023-10-30-07-28-53.png)

# %% [markdown]
# ![](2023-10-30-07-29-06.png)

# %% [markdown]
# ![](2023-10-30-07-30-11.png)

# %% [markdown]
# ![](2023-10-30-07-31-09.png)

# %% [markdown]
# ![](2023-10-30-07-30-40.png)

# %% [markdown]
# ![](2023-10-30-07-32-02.png)

# %% [markdown]
# ![](2023-10-30-07-32-22.png)

# %% [markdown]
# ![](2023-10-30-07-33-16.png)

# %% [markdown]
# ![](2023-10-30-07-34-22.png)

# %% [markdown]
# ![](2023-10-30-07-35-51.png)

# %% [markdown]
# ![](2023-10-30-07-36-22.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![](2023-10-30-07-37-33.png)

# %% [markdown]
# ![](2023-10-30-07-38-07.png)

# %% [markdown]
# ![](2023-10-30-07-39-09.png)

# %% [markdown]
# ![](2023-10-30-07-42-24.png)

# %% [markdown]
# ![](2023-10-30-07-42-54.png)

# %% [markdown]
# ![](2023-10-30-07-44-06.png)

# %% [markdown]
# ![](2023-10-30-07-44-56.png)

# %% [markdown]
# ![](2023-10-30-07-45-36.png)

# %% [markdown]
# ![](2023-10-30-07-46-12.png)

# %% [markdown]
# ![](2023-10-30-07-46-28.png)

# %% [markdown]
# ![](2023-10-30-07-46-53.png)

# %% [markdown]
# ![](2023-10-30-07-51-10.png)

# %% [markdown]
# ![](2023-10-30-07-51-32.png)

# %% [markdown]
# ![](2023-10-30-07-52-05.png)

# %% [markdown]
# ![](2023-10-30-07-52-26.png)

# %% [markdown]
# ![](2023-10-30-07-52-47.png)

# %% [markdown]
# ![](2023-10-30-07-53-11.png)

# %% [markdown]
# ![](2023-10-30-07-53-28.png)

# %% [markdown]
# ![](2023-10-30-07-54-04.png)

# %% [markdown]
# ![](2023-10-30-07-54-25.png)

# %% [markdown]
# ![](2023-10-30-07-55-47.png)

# %% [markdown]
# ![](2023-10-30-07-56-05.png)

# %% [markdown]
# ![](2023-10-30-07-57-03.png)

# %% [markdown]
# ![](2023-10-30-07-57-40.png)

# %% [markdown]
# ![](2023-10-30-07-58-36.png)

# %% [markdown]
# ![](2023-10-30-08-01-38.png)

# %% [markdown]
# ![](2023-10-30-08-03-15.png)

# %% [markdown]
# ![](2023-10-30-08-03-58.png)

# %% [markdown]
# ![](2023-10-30-08-04-43.png)

# %% [markdown]
# ![](2023-10-30-08-05-25.png)

# %% [markdown]
# ![](2023-10-30-08-08-11.png)

# %% [markdown]
# ![](2023-10-30-08-09-38.png)

# %% [markdown]
# ![](2023-10-30-08-10-08.png)

# %% [markdown]
# ### **Bell's Inequality**

# %% [markdown]
# ![](2023-10-30-18-29-29.png)

# %% [markdown]
# ![](2023-10-30-18-30-05.png)

# %% [markdown]
# ![](2023-10-30-18-31-01.png)

# %% [markdown]
# ![](2023-10-30-18-37-58.png)

# %% [markdown]
# ![](2023-10-30-18-38-52.png)

# %% [markdown]
# ![](2023-10-30-18-39-25.png)

# %% [markdown]
# ![](2023-10-30-18-40-35.png)

# %% [markdown]
# ![](2023-10-30-18-41-09.png)

# %% [markdown]
# ![](2023-10-30-18-42-11.png)

# %% [markdown]
# ![](2023-10-30-18-43-04.png)

# %% [markdown]
# ![](2023-10-30-18-44-10.png)

# %% [markdown]
# ![](2023-10-30-18-45-12.png)

# %% [markdown]
# ![](2023-10-30-18-46-40.png)

# %% [markdown]
# ![](2023-10-30-18-48-46.png)

# %% [markdown]
# ![](2023-10-30-18-49-46.png)

# %% [markdown]
# ![](2023-10-30-18-51-28.png)

# %% [markdown]
# ### **Grover Search Algorithm**

# %% [markdown]
# ![](2023-10-30-18-54-28.png)

# %% [markdown]
# ![](2023-10-30-18-55-43.png)

# %% [markdown]
# ![](2023-10-30-18-56-37.png)

# %% [markdown]
# ![](2023-10-30-18-57-52.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![](2023-10-30-19-00-34.png)

# %% [markdown]
# ![](2023-10-30-19-01-33.png)

# %% [markdown]
# ![](2023-10-30-19-03-03.png)

# %% [markdown]
# #### **The Algorithm**

# %% [markdown]
# ![](2023-10-30-19-59-14.png)

# %% [markdown]
# ![](2023-10-30-19-59-47.png)

# %% [markdown]
# ![](2023-10-30-20-01-27.png)

# %% [markdown]
# ![](2023-10-30-20-02-10.png)

# %% [markdown]
# ![](2023-10-30-20-02-45.png)

# %% [markdown]
# ![](2023-10-30-20-03-11.png)

# %% [markdown]
# ![](2023-10-30-20-03-46.png)

# %% [markdown]
# ![](2023-10-30-20-05-07.png)

# %% [markdown]
# ![](2023-10-30-20-05-46.png)

# %% [markdown]
# ![](2023-10-30-20-07-10.png)

# %% [markdown]
# ![](2023-10-30-20-07-57.png)

# %% [markdown]
# ![](2023-10-30-20-08-30.png)

# %% [markdown]
# ![](2023-10-30-20-09-08.png)

# %% [markdown]
# ![](2023-10-30-20-09-24.png)

# %% [markdown]
# ![](2023-10-30-20-10-05.png)

# %% [markdown]
# ![](2023-10-30-20-10-30.png)

# %% [markdown]
# ![](2023-10-30-20-11-04.png)

# %% [markdown]
# ![](2023-10-30-20-11-21.png)

# %% [markdown]
# ![](2023-10-30-20-11-48.png)

# %% [markdown]
# ![](2023-10-30-20-12-44.png)

# %% [markdown]
# ![](2023-10-30-20-13-15.png)

# %% [markdown]
# ![](2023-10-30-20-13-35.png)

# %% [markdown]
# ![](2023-10-30-20-57-30.png)

# %% [markdown]
# ![](2023-10-30-21-11-50.png)

# %% [markdown]
# ![](2023-10-30-21-24-43.png)

# %% [markdown]
# ![](2023-10-30-21-25-17.png)

# %% [markdown]
# ![](2023-10-30-21-27-36.png)

# %% [markdown]
# ![](2023-10-30-21-31-49.png)

# %% [markdown]
# ![](2023-10-30-21-47-05.png)

# %% [markdown]
# ![](2023-10-30-21-49-48.png)

# %% [markdown]
# ![](2023-10-30-21-51-54.png)

# %% [markdown]
# ![](2023-10-30-21-53-03.png)

# %% [markdown]
# ![](2023-10-30-21-56-36.png)

# %% [markdown]
# ![](2023-10-30-21-55-57.png)

# %% [markdown]
# ![](2023-10-30-22-04-19.png)

# %% [markdown]
# ![](2023-10-30-22-04-35.png)

# %% [markdown]
# ![](2023-10-30-22-05-29.png)

# %% [markdown]
# ![](2023-10-30-22-06-06.png)

# %% [markdown]
# ![](2023-10-30-22-06-53.png)

# %% [markdown]
# ![](2023-10-30-22-07-34.png)

# %% [markdown]
# ![](2023-10-30-22-13-44.png)

# %% [markdown]
# ![](2023-10-30-22-14-03.png)

# %% [markdown]
# ![](2023-10-30-22-14-32.png)

# %% [markdown]
# ### **Short Algorithm for Factoring RSA Numbers**

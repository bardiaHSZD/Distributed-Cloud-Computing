# %% [markdown]
# # **Week Topic: Generative AI use cases, project lifecycle, and model pre-training**

# %% [markdown]
# ## **Generative AI & LLMs**

# %% [markdown]
# ![](2024-04-19-03-36-55.png)

# %% [markdown]
# ![](2024-04-19-03-38-36.png)

# %% [markdown]
# ![](2024-04-19-03-39-56.png)

# %% [markdown]
# ## **LLM use cases and tasks**

# %% [markdown]
# ![](2024-04-19-03-41-47.png)

# %% [markdown]
# ![](2024-04-19-03-42-35.png)

# %% [markdown]
# ![](2024-04-19-03-43-21.png)

# %% [markdown]
# Smaller models can be fine tuned over specific tasks.

# %% [markdown]
# ## **Text generation before transformers**

# %% [markdown]
# ![](2024-04-19-03-45-38.png)

# %% [markdown]
# ![](2024-04-19-03-46-37.png)

# %% [markdown]
# ![](2024-04-19-03-46-59.png)

# %% [markdown]
# ![](2024-04-19-03-47-35.png)

# %% [markdown]
# ## **Transformers architecture**

# %% [markdown]
# ![](2024-04-19-03-49-04.png)

# %% [markdown]
# ![](2024-04-19-03-49-42.png)

# %% [markdown]
# ![](2024-04-19-03-50-37.png)

# %% [markdown]
# ![](2024-04-19-03-51-14.png)

# %% [markdown]
# ![](2024-04-19-03-52-10.png)

# %% [markdown]
# ![](2024-04-19-03-52-54.png)

# %% [markdown]
# ![](2024-04-19-03-53-25.png)

# %% [markdown]
# ![](2024-04-19-03-53-48.png)

# %% [markdown]
# ![](2024-04-19-03-54-38.png)

# %% [markdown]
# ![](2024-04-19-03-54-55.png)

# %% [markdown]
# ## **Generating text with transformers**

# %% [markdown]
# ![](2024-04-19-03-57-28.png)

# %% [markdown]
# ![](2024-04-19-03-57-56.png)

# %% [markdown]
# ![](2024-04-19-03-58-47.png)

# %% [markdown]
# ![](2024-04-19-03-59-18.png)

# %% [markdown]
# ![](2024-04-19-04-00-12.png)

# %% [markdown]
# ![](2024-04-19-04-01-44.png)

# %% [markdown]
# ![](2024-04-19-04-02-11.png)

# %% [markdown]
# ![](2024-04-19-04-03-34.png)

# %% [markdown]
# ![](2024-04-19-04-03-56.png)

# %% [markdown]
# ![](2024-04-19-04-04-15.png)

# %% [markdown]
# ![](2024-04-19-04-04-40.png)

# %% [markdown]
# ![](2024-04-19-04-04-54.png)

# %% [markdown]
# ![](2024-04-19-04-07-12.png)

# %% [markdown]
# ## **Prompting and prompt engineering**

# %% [markdown]
# ![](2024-04-19-04-48-47.png)

# %% [markdown]
# ![](2024-04-19-04-49-21.png)

# %% [markdown]
# ## **Generative configuration**

# %% [markdown]
# ![](2024-04-19-06-46-43.png)

# %% [markdown]
# ![](2024-04-19-06-47-39.png)

# %% [markdown]
# ![](2024-04-19-06-49-09.png)

# %% [markdown]
# ![](2024-04-19-06-50-20.png)

# %% [markdown]
# ![](2024-04-19-06-50-46.png)

# %% [markdown]
# ![](2024-04-19-06-51-13.png)

# %% [markdown]
# ![](2024-04-19-06-51-58.png)

# %% [markdown]
# ![](2024-04-19-06-52-29.png)

# %% [markdown]
# ![](2024-04-19-06-53-25.png)

# %% [markdown]
# ![](2024-04-19-06-54-02.png)

# %% [markdown]
# Leaving the temperature at 1 will not alter the softmax probability distribution.

# %% [markdown]
# ## **Generative AI project lifecycle**

# %% [markdown]
# ![](2024-04-19-07-04-27.png)

# %% [markdown]
# ![](2024-04-19-07-04-40.png)

# %% [markdown]
# ![](2024-04-19-07-06-15.png)

# %% [markdown]
# ![](2024-04-19-07-06-46.png)

# %% [markdown]
# ## **Introduction to AWS labs**

# %% [markdown]
# ![](2024-04-19-07-18-54.png)

# %% [markdown]
# ![](2024-04-19-07-19-49.png)

# %% [markdown]
# ![](2024-04-19-07-20-50.png)

# %% [markdown]
# ![](2024-04-19-07-21-26.png)

# %% [markdown]
# ![](2024-04-19-07-21-57.png)

# %% [markdown]
# ![](2024-04-19-07-22-34.png)

# %% [markdown]
# ![](2024-04-19-07-23-00.png)

# %% [markdown]
# ![](2024-04-19-07-23-24.png)

# %% [markdown]
# ## **Lab 1 walkthrough**

# %% [markdown]
# ![](2024-04-19-08-51-19.png)

# %% [markdown]
# ![](2024-04-19-08-52-34.png)

# %% [markdown]
# ![](2024-04-19-08-53-15.png)

# %% [markdown]
# ![](2024-04-19-08-54-08.png)

# %% [markdown]
# ![](2024-04-19-08-55-02.png)

# %% [markdown]
# ![](2024-04-19-08-55-42.png)

# %% [markdown]
# ![](2024-04-19-09-01-35.png)

# %% [markdown]
# ![](2024-04-19-09-02-29.png)

# %% [markdown]
# ![](2024-04-19-09-04-19.png)

# %% [markdown]
# ![](2024-04-19-09-05-58.png)

# %% [markdown]
# ![](2024-04-19-09-06-52.png)

# %% [markdown]
# ![](2024-04-19-09-09-41.png)

# %% [markdown]
# ## **Pre-training large language models**

# %% [markdown]
# ![](2024-04-19-09-20-18.png)

# %% [markdown]
# ![](2024-04-19-09-21-48.png)

# %% [markdown]
# ![](2024-04-19-09-22-29.png)

# %% [markdown]
# ![](2024-04-19-09-23-01.png)

# %% [markdown]
# ![](2024-04-19-09-23-43.png)

# %% [markdown]
# ![](2024-04-19-09-24-05.png)

# %% [markdown]
# ![](2024-04-19-09-24-46.png)

# %% [markdown]
# ![](2024-04-19-09-24-59.png)

# %% [markdown]
# ![](2024-04-19-09-26-21.png)

# %% [markdown]
# ## **Computational challenges of training LLMs**

# %% [markdown]
# ![](2024-04-19-09-28-30.png)

# %% [markdown]
# ![](2024-04-19-09-28-42.png)

# %% [markdown]
# ![](2024-04-19-09-29-10.png)

# %% [markdown]
# ![](2024-04-19-09-31-35.png)

# %% [markdown]
# ![](2024-04-19-09-31-45.png)

# %% [markdown]
# ![](2024-04-19-09-31-57.png)

# %% [markdown]
# ![](2024-04-19-09-32-17.png)

# %% [markdown]
# ![](2024-04-19-09-33-50.png)

# %% [markdown]
# ![](2024-04-19-09-34-27.png)

# %% [markdown]
# ![](2024-04-19-09-34-56.png)

# %% [markdown]
# ![](2024-04-19-09-35-23.png)

# %% [markdown]
# ## **Efficient multi-GPU compute strategies**

# %% [markdown]
# ![](2024-04-19-09-52-21.png)

# %% [markdown]
# ![](2024-04-19-09-52-46.png)

# %% [markdown]
# ![](2024-04-19-09-53-47.png)

# %% [markdown]
# ![](2024-04-19-09-54-14.png)

# %% [markdown]
# ![](2024-04-19-10-07-02.png)

# %% [markdown]
# ![](2024-04-19-10-07-57.png)

# %% [markdown]
# ![](2024-04-19-10-08-06.png)

# %% [markdown]
# ![](2024-04-19-10-09-28.png)

# %% [markdown]
# ![](2024-04-19-10-10-35.png)

# %% [markdown]
# ## **Scaling laws and compute-optimal models**

# %% [markdown]
# ![](2024-04-19-10-13-03.png)

# %% [markdown]
# ![](2024-04-19-10-14-02.png)

# %% [markdown]
# ![](2024-04-19-10-14-27.png)

# %% [markdown]
# ![](2024-04-19-10-15-11.png)

# %% [markdown]
# ![](2024-04-19-10-16-23.png)

# %% [markdown]
# ![](2024-04-19-10-17-23.png)

# %% [markdown]
# ![](2024-04-19-10-17-48.png)

# %% [markdown]
# ![](2024-04-19-10-18-43.png)

# %% [markdown]
# ![](2024-04-19-10-19-27.png)

# %% [markdown]
# ![](2024-04-19-10-19-59.png)

# %% [markdown]
# ![](2024-04-19-10-20-46.png)

# %% [markdown]
# ## **Pre-training for domain adaptation**

# %% [markdown]
# ![](2024-04-19-10-23-54.png)

# %% [markdown]
# ![](2024-04-19-10-24-53.png)

# %% [markdown]
# ![](2024-04-19-10-25-17.png)

# %% [markdown]
# ![](2024-04-19-10-25-56.png)

# %% [markdown]
# ## **Domain-specific training: BloombergGPT**

# %% [markdown]
# ![](2024-04-19-09-50-15.png)

# %% [markdown]
# ## **Introduction**

# %% [markdown]
# ## **Introduction**

# %% [markdown]
# ## **Introduction**

# %% [markdown]
# ## **Introduction**

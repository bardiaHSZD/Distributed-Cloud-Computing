# %% [markdown]
# # **Fine-tuning and evaluating large language models**

# %% [markdown]
# ## **Instruction fine-tuning**

# %% [markdown]
# ![](2024-04-20-00-31-42.png)

# %% [markdown]
# ![](2024-04-20-00-32-00.png)

# %% [markdown]
# ![](2024-04-20-00-32-58.png)

# %% [markdown]
# ![](2024-04-20-00-33-36.png)

# %% [markdown]
# ![](2024-04-20-00-34-01.png)

# %% [markdown]
# ![](2024-04-20-00-34-48.png)

# %% [markdown]
# ![](2024-04-20-00-35-11.png)

# %% [markdown]
# ![](2024-04-20-00-37-18.png)

# %% [markdown]
# ![](2024-04-20-00-37-38.png)

# %% [markdown]
# ![](2024-04-20-00-39-00.png)

# %% [markdown]
# ![](2024-04-20-00-39-33.png)

# %% [markdown]
# ![](2024-04-20-00-39-59.png)

# %% [markdown]
# ![](2024-04-20-00-41-03.png)

# %% [markdown]
# ![](2024-04-20-00-41-26.png)

# %% [markdown]
# ![](2024-04-20-00-41-46.png)

# %% [markdown]
# ## **Fine-tuning on a single task**

# %% [markdown]
# ![](2024-04-20-01-20-05.png)

# %% [markdown]
# ![](2024-04-20-01-20-43.png)

# %% [markdown]
# ![](2024-04-20-01-21-54.png)

# %% [markdown]
# ## **Multi-task instruction fine-tuning**

# %% [markdown]
# ![](2024-04-20-03-44-50.png)

# %% [markdown]
# ![](2024-04-20-03-45-45.png)

# %% [markdown]
# ![](2024-04-20-03-46-11.png)

# %% [markdown]
# ![](2024-04-20-03-46-49.png)

# %% [markdown]
# ![](2024-04-20-03-47-23.png)

# %% [markdown]
# ![](2024-04-20-03-48-51.png)

# %% [markdown]
# ![](2024-04-20-03-50-17.png)

# %% [markdown]
# ![](2024-04-20-03-50-46.png)

# %% [markdown]
# ![](2024-04-20-03-51-48.png)

# %% [markdown]
# ![](2024-04-20-03-52-06.png)

# %% [markdown]
# ![](2024-04-20-03-52-47.png)

# %% [markdown]
# ![](2024-04-20-03-53-35.png)

# %% [markdown]
# ![](2024-04-20-03-54-31.png)

# %% [markdown]
# ## **Scaling instruct models**

# %% [markdown]
# ![](2024-04-20-00-06-17.png)

# %% [markdown]
# ## **Model Evaluation**

# %% [markdown]
# ![](2024-04-20-03-57-07.png)

# %% [markdown]
# ![](2024-04-20-03-57-44.png)

# %% [markdown]
# ![](2024-04-20-03-58-17.png)

# %% [markdown]
# ![](2024-04-20-03-58-46.png)

# %% [markdown]
# ![](2024-04-20-03-59-56.png)

# %% [markdown]
# ![](2024-04-20-04-00-35.png)

# %% [markdown]
# ![](2024-04-20-04-01-26.png)

# %% [markdown]
# ![](2024-04-20-04-02-27.png)

# %% [markdown]
# ![](2024-04-20-04-02-56.png)

# %% [markdown]
# ![](2024-04-20-04-03-20.png)

# %% [markdown]
# ![](2024-04-20-04-04-25.png)

# %% [markdown]
# ![](2024-04-20-04-18-37.png)

# %% [markdown]
# ![](2024-04-20-04-20-43.png)

# %% [markdown]
# ## **Benchmarks**

# %% [markdown]
# ![](2024-04-20-04-22-27.png)

# %% [markdown]
# ![](2024-04-20-04-22-54.png)

# %% [markdown]
# ![](2024-04-20-04-23-14.png)

# %% [markdown]
# ![](2024-04-20-04-23-26.png)

# %% [markdown]
# ![](2024-04-20-04-24-19.png)

# %% [markdown]
# ![](2024-04-20-04-24-48.png)

# %% [markdown]
# ![](2024-04-20-04-25-14.png)

# %% [markdown]
# ## **Parameter efficient fine-tuning (PEFT)**

# %% [markdown]
# ![](2024-04-20-04-27-52.png)

# %% [markdown]
# ![](2024-04-20-04-28-22.png)

# %% [markdown]
# ![](2024-04-20-04-28-57.png)

# %% [markdown]
# ![](2024-04-20-04-29-33.png)

# %% [markdown]
# ![](2024-04-20-04-30-36.png)

# %% [markdown]
# ![](2024-04-20-04-31-00.png)

# %% [markdown]
# ![](2024-04-20-04-31-23.png)

# %% [markdown]
# ## **PEFT techniques 1: LoRA**

# %% [markdown]
# ![](2024-04-20-04-39-15.png)

# %% [markdown]
# ![](2024-04-20-04-40-26.png)

# %% [markdown]
# ![](2024-04-20-04-40-43.png)

# %% [markdown]
# ![](2024-04-20-04-41-02.png)

# %% [markdown]
# ![](2024-04-20-04-42-04.png)

# %% [markdown]
# ![](2024-04-20-04-43-10.png)

# %% [markdown]
# ![](2024-04-20-04-43-28.png)

# %% [markdown]
# ![](2024-04-20-04-59-23.png)

# %% [markdown]
# ![](2024-04-20-05-00-40.png)

# %% [markdown]
# ![](2024-04-20-05-01-29.png)

# %% [markdown]
# ## **PEFT techniques 2: Soft prompts**

# %% [markdown]
# ![](2024-04-20-05-05-23.png)

# %% [markdown]
# ![](2024-04-20-05-05-52.png)

# %% [markdown]
# ![](2024-04-20-05-06-28.png)

# %% [markdown]
# ![](2024-04-20-05-07-18.png)

# %% [markdown]
# ![](2024-04-20-05-08-12.png)

# %% [markdown]
# ![](2024-04-20-05-08-59.png)

# %% [markdown]
# By the way you can also combine LoRA with the quantization techniques you learned
# about in week 1 to further reduce your memory footprint.
# This is known as QLoRA in practice,
# PEFT is used heavily to minimize compute and memory resources.
# And ultimately reducing the cost of fine tuning, allowing you to make the most
# of your compute budget and speed up your development process.

# %% [markdown]
# ## **Lab 2 walkthrough**

# %% [markdown]
# ![](2024-04-20-05-35-17.png)

# %% [markdown]
# ![](2024-04-20-05-38-45.png)

# %% [markdown]
# ![](2024-04-20-05-39-34.png)

# %% [markdown]
# ![](2024-04-20-05-40-22.png)

# %% [markdown]
# ![](2024-04-20-05-40-39.png)

# %% [markdown]
# ![](2024-04-20-05-47-52.png)

# %% [markdown]
# ![](2024-04-20-05-50-51.png)

# %% [markdown]
# ![](2024-04-20-05-51-28.png)

# %% [markdown]
# ![](2024-04-20-07-40-40.png)

# %% [markdown]
# ![](2024-04-20-07-41-21.png)

# %% [markdown]
# ![](2024-04-20-07-42-18.png)

# %% [markdown]
# ![](2024-04-20-08-26-11.png)

# %% [markdown]
# ![](2024-04-20-08-26-35.png)

# %% [markdown]
# ![](2024-04-20-08-27-24.png)

# %% [markdown]
# ![](2024-04-20-08-28-05.png)

# %% [markdown]
# ![](2024-04-20-08-29-01.png)

# %% [markdown]
# ![](2024-04-20-08-29-40.png)

# %% [markdown]
# ![](2024-04-20-08-30-08.png)

# %% [markdown]
# ![](2024-04-20-10-30-26.png)

# %% [markdown]
# ![](2024-04-20-10-31-02.png)

# %% [markdown]
# ![](2024-04-20-10-32-21.png)

# %% [markdown]
# ![](2024-04-20-10-32-57.png)

# %% [markdown]
# ![](2024-04-20-10-46-47.png)

# %% [markdown]
# ![](2024-04-20-10-56-04.png)

# %% [markdown]
# ![](2024-04-20-11-17-25.png)

# %% [markdown]
# ![](2024-04-20-11-21-29.png)

# %% [markdown]
# ![](2024-04-20-11-33-04.png)

# %% [markdown]
# ![](2024-04-20-12-46-41.png)

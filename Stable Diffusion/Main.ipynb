# %% [markdown]
# # **Week Topic**

# %% [markdown]
# ## **Intuition**

# %% [markdown]
# ![](2024-04-25-03-20-12.png)

# %% [markdown]
# ![](2024-04-25-03-20-53.png)

# %% [markdown]
# ![](2024-04-25-03-21-20.png)

# %% [markdown]
# ![](2024-04-25-03-21-52.png)

# %% [markdown]
# ![](2024-04-25-03-31-10.png)

# %% [markdown]
# ## **Introduction**

# %% [markdown]
# ## **Introduction**

# %% [markdown]
# ## **Introduction**

# %% [markdown]
# ## **Introduction**

# %% [markdown]
# ## **Introduction**

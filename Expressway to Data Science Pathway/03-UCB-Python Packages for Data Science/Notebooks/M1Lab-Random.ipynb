# %% [markdown]
# #Welcome to our Lab practice!
#
# This lab is all about the package, random. Are you ready? Let's go!
#
# You will find some small tasks in sections below.
#
# > Try to figure out by yourself, or search for references. Being able to search and find information needed is an important skill that benefits you and your career for a long time.

# %% [markdown]
# ## Random Int

# %% [markdown]
# ### Task: Generate a random positive integer less than 10.

# %%
# your code is here

# %% [markdown]
# ### Task: Generate a random integer within 0 (inclusive) and 100 (inclusive)

# %%
import random
print(random.randint(0,100))
# Out:
# 99

# %% [markdown]
# ### Task: Generate a random integer within a and b, where a and b are user entered integers and a $<=$ b

# %%
# your code is here

# %% [markdown]
# ## Random Float

# %% [markdown]
# ### Task: Generate a random float number between 0 and 1
# > hint: use random()

# %%
import random
print(random.random())
# Out:
# 0.27758431163324315

# %% [markdown]
# ### Task: Generate a random float number between 0 and 10.
# > hint: use uniform()

# %%
import random
print(random.uniform(0,10))
# Out:
# 4.904759632950688

# %% [markdown]
# ### Task: Generate a random float number between 5 and 10
# >hint: use uniform()

# %%
# your code is here

# %% [markdown]
# ### Task: Generate a random float number based on the Gaussian distribution
# > hint: search and learn gauss()

# %%
# your code is here

# %% [markdown]
# ## Random Datasets
#
# ### Genearte a list of 1000 random floats within 0 and 1.

# %%
import random
rand_list = []
for i in range(1000):
    rand_list.append(random.random())
    
print(rand_list)
# Out:
# [0.548692383357925, 0.6171775337806689, 0.5142791123114557, 0.6142579283746985, 0.5301070590707362, 0.2540448544291487, 0.7776866467834884, 0.9749753242589821, 0.42692703000156385, 0.7029984817853081, 0.5425602569389799, 0.8346506532970714, 0.9440153588708105, 0.9502517514512656, 0.8392224655549759, 0.5399860755872009, 0.6064025670881575, 0.37946866541870594, 0.15412117943641623, 0.6349197977116351, 0.507561689823795, 0.04189880396707213, 0.4144447360967627, 0.8111709715845679, 0.07827185668109571, 0.7762102289237087, 0.8843100205500236, 0.19147058431053143, 0.7614099527439298, 0.7881611364124388, 0.5765206991949865, 0.46539771517246575, 0.02981965267713771, 0.547224614859306, 0.4557298310411998, 0.8152634570648386, 0.7095114324362849, 0.8869229787269856, 0.0032463278414731622, 0.59275351572515, 0.9571359538180131, 0.21556799630836265, 0.45625602328343584, 0.5309327189513474, 0.7814045665016381, 0.14186463927660253, 0.7575170795784075, 0.23205854482112576, 0.1160723488570502, 0.2363749286618918, 0.16642689559338597, 0.5739986508458484, 0.15536562116132102, 0.43917658828825157, 0.5374417356717833, 0.6717514675270462, 0.26080338190228036, 0.8263151529298424, 0.3384696340403134, 0.2989246230463277, 0.795478794515983, 0.7527680383848381, 0.0918228132567167, 0.7986145917002953, 0.5463449780567168, 0.15380477833368877, 0.7504299250647031, 0.5027727825274176, 0.37886366402771887, 0.00281393077826797, 0.7094508259113085, 0.40214069934864594, 0.09325423859901161, 0.05801403091486301, 0.06719354544734601, 0.4986579982012711, 0.9680122845061047, 0.37938965696652627, 0.978852253034772, 0.16974766619319703, 0.46332689056134935, 0.810954240620323, 0.520394294622918, 0.5440616336197804, 0.0059190829911035525, 0.6659129007132287, 0.5753706985685073, 0.32361963803040816, 0.6842493964424219, 0.44234317954971303, 0.596801982498715, 0.9634517598325171, 0.7238193900952057, 0.6399085686103361, 0.34394758186705, 0.7361964591994804, 0.13480350780663464, 0.49479564144473187, 0.701719077308817, 0.9473192985770672, 0.25865160775113927, 0.3599975855890176, 0.9001002379986645, 0.07216110484644278, 0.6156881393214929, 0.7413440870407901, 0.9121243721389142, 0.1494404676187142, 0.8119302426687299, 0.23567263015965234, 0.9516520342176561, 0.10228641235480784, 0.43719564840567715, 0.07295247403516181, 0.9080263331730276, 0.1325956120258569, 0.27349631842868916, 0.09049044122059491, 0.6344000748571796, 0.7440210291658004, 0.6657022877967673, 0.6637237125074956, 0.1237668024128159, 0.644442728940025, 0.9551796459027341, 0.7591746018386603, 0.472013147323461, 0.21397946727040218, 0.311501567220674, 0.7677769209086147, 0.13591729857084123, 0.6647083020746056, 0.8323863431354822, 0.8038427457997354, 0.29204039810399185, 0.38248882891169955, 0.008628047239626957, 0.26932279246290736, 0.4783222352215003, 0.09608761174986324, 0.27130654046323566, 0.89834638838191, 0.25659612719224356, 0.1275089348454468, 0.4777098457188793, 0.5270955568136442, 0.7483713262822247, 0.8355776843166837, 0.070869065155576, 0.8688182075371779, 0.24045632862344213, 0.07352901919495969, 0.22651242832356255, 0.9111754552215912, 0.9894549202293618, 0.9832013819411642, 0.7781611592093042, 0.822378357095827, 0.48638450686413837, 0.5379114757529457, 0.5167531129522784, 0.5113396410720157, 0.1405235674071995, 0.07118702700148694, 0.5188229958807044, 0.4846066063678155, 0.1202202142182982, 0.7366951685701926, 0.40466404914231013, 0.9228780211918849, 0.10528936243075582, 0.1544483134224206, 0.09161189275991288, 0.6000864352649342, 0.45292321639291755, 0.6022582994352861, 0.9606674726307638, 0.33438599607177777, 0.7690439961909171, 0.849846333496643, 0.8535206901343165, 0.06499292535066326, 0.023777552635114496, 0.3364422196017838, 0.5612371198413536, 0.5142680056365347, 0.7165318879881756, 0.002110328968058739, 0.47593619387722075, 0.6899650224022704, 0.4661436138025278, 0.7824900943597993, 0.2729792701269037, 0.2893998187153437, 0.18704893339547035, 0.7535093965622323, 0.31860580613018064, 0.505043 ...

# %% [markdown]
# ### Generate a list of 1000 random integers within 0 and 1.

# %%
# your code is here

# %% [markdown]
# ### Generate a list of 1000 numbers following normal distribution with 10 as mean, and 1 as standard derivation.

# %%
# your code is here

# %% [markdown]
# ## Explore random module
#
# random module has many other functions besides random(), randint(), and the ones we have used above. Please search and explore by yourself -- this is a skill more important than learning materials presented to you. In your future career, you will have to explore unknown, and learn new skills, all the time.

# %%
# Your exploration is here

# %% [markdown]
# ## Explore math module
#
# math module is another interesting and useful module to help you deal with math. Explore and learn by yourself.

# %%
# Your exploration is here

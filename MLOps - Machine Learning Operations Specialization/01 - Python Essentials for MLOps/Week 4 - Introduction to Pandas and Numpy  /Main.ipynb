# %% [markdown]
# # **Introduction to Pandas and Numpy**

# %% [markdown]
# ## **Basic Pandas Usage**

# %% [markdown]
# ![](2024-02-05-01-08-37.png)

# %% [markdown]
# ![](2024-02-05-08-55-24.png)

# %% [markdown]
# ![](2024-02-05-08-57-31.png)

# %% [markdown]
# ![](2024-02-05-09-00-11.png)

# %% [markdown]
# ![](2024-02-05-09-01-06.png)

# %% [markdown]
# ![](2024-02-05-09-01-58.png)

# %% [markdown]
# ![](2024-02-05-09-03-06.png)

# %% [markdown]
# ![](2024-02-05-09-03-56.png)

# %% [markdown]
# ![](2024-02-05-09-04-46.png)

# %% [markdown]
# ![](2024-02-05-09-06-08.png)

# %% [markdown]
# ![](2024-02-05-09-06-59.png)

# %% [markdown]
# ![](2024-02-05-09-08-56.png)

# %% [markdown]
# ![](2024-02-05-09-09-37.png)

# %% [markdown]
# ![](2024-02-05-09-09-48.png)

# %% [markdown]
# ![](2024-02-05-09-11-26.png)

# %% [markdown]
# ![](2024-02-05-09-12-11.png)

# %% [markdown]
# ![](2024-02-05-09-12-45.png)

# %% [markdown]
# ![](2024-02-05-09-13-38.png)

# %% [markdown]
# ![](2024-02-05-09-13-59.png)

# %% [markdown]
# ## **Working with Dataframes**

# %% [markdown]
# ![](2024-02-05-01-27-52.png)

# %% [markdown]
# ![](2024-02-05-09-39-34.png)

# %% [markdown]
# ![](2024-02-05-09-41-24.png)

# %% [markdown]
# ![](2024-02-05-09-41-42.png)

# %% [markdown]
# ![](2024-02-05-09-42-31.png)

# %% [markdown]
# ![](2024-02-05-09-43-47.png)

# %% [markdown]
# ![](2024-02-05-09-44-32.png)

# %% [markdown]
# ![](2024-02-05-09-45-39.png)

# %% [markdown]
# ![](2024-02-05-09-46-42.png)

# %% [markdown]
# ![](2024-02-05-21-28-51.png)

# %% [markdown]
# ![](2024-02-05-21-28-05.png)

# %% [markdown]
# ![](2024-02-05-21-37-07.png)

# %% [markdown]
# ![](2024-02-05-21-38-28.png)

# %% [markdown]
# ![](2024-02-05-21-39-15.png)

# %% [markdown]
# ![](2024-02-05-21-41-35.png)

# %% [markdown]
# ![](2024-02-05-21-43-39.png)

# %% [markdown]
# ## **Numpy Basics**

# %% [markdown]
# ![](2024-02-05-01-34-49.png)

# %% [markdown]
# ![](2024-02-05-21-45-11.png)

# %% [markdown]
# ![](2024-02-05-21-46-22.png)

# %% [markdown]
# ![](2024-02-05-21-46-52.png)

# %% [markdown]
# ![](2024-02-05-21-47-26.png)

# %% [markdown]
# ![](2024-02-05-21-48-32.png)

# %% [markdown]
# ![](2024-02-05-21-48-58.png)

# %% [markdown]
# ![](2024-02-05-21-51-59.png)

# %% [markdown]
# ![](2024-02-05-21-52-53.png)

# %% [markdown]
# ![](2024-02-05-21-53-53.png)

# %% [markdown]
# # **Introduction to Pandas and Numpy**

# %% [markdown]
# ## **Basic Pandas Usage**

# %% [markdown]
# ![](2024-02-05-01-08-37.png)

# %% [markdown]
# ![](2024-02-05-08-55-24.png)

# %% [markdown]
# ![](2024-02-05-08-57-31.png)

# %% [markdown]
# ![](2024-02-05-09-00-11.png)

# %% [markdown]
# ![](2024-02-05-09-01-06.png)

# %% [markdown]
# ![](2024-02-05-09-01-58.png)

# %% [markdown]
# ![](2024-02-05-09-03-06.png)

# %% [markdown]
# ![](2024-02-05-09-03-56.png)

# %% [markdown]
# ![](2024-02-05-09-04-46.png)

# %% [markdown]
# ![](2024-02-05-09-06-08.png)

# %% [markdown]
# ![](2024-02-05-09-06-59.png)

# %% [markdown]
# ![](2024-02-05-09-08-56.png)

# %% [markdown]
# ![](2024-02-05-09-09-37.png)

# %% [markdown]
# ![](2024-02-05-09-09-48.png)

# %% [markdown]
# ![](2024-02-05-09-11-26.png)

# %% [markdown]
# ![](2024-02-05-09-12-11.png)

# %% [markdown]
# ![](2024-02-05-09-12-45.png)

# %% [markdown]
# ![](2024-02-05-09-13-38.png)

# %% [markdown]
# ![](2024-02-05-09-13-59.png)

# %% [markdown]
# ## **Working with Dataframes**

# %% [markdown]
# ![](2024-02-05-01-27-52.png)

# %% [markdown]
# ## **Numpy Basics**

# %% [markdown]
# ![](2024-02-05-01-34-49.png)

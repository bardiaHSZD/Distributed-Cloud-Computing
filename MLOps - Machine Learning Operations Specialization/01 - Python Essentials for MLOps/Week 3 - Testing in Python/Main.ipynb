# %% [markdown]
# # **Testing in Python**

# %% [markdown]
# ## **Introduction to Testing**

# %% [markdown]
# ![](2024-02-03-23-28-12.png)

# %% [markdown]
# ![](2024-02-04-01-17-54.png)

# %% [markdown]
# ![](2024-02-04-01-18-23.png)

# %% [markdown]
# ![](2024-02-04-01-19-35.png)

# %% [markdown]
# ![](2024-02-04-01-20-26.png)

# %% [markdown]
# ![](2024-02-04-01-21-53.png)

# %% [markdown]
# ![](2024-02-04-01-23-03.png)

# %% [markdown]
# ![](2024-02-04-01-24-25.png)

# %% [markdown]
# ![](2024-02-04-01-25-02.png)

# %% [markdown]
# ![](2024-02-04-01-26-01.png)

# %% [markdown]
# ![](2024-02-04-01-26-35.png)

# %% [markdown]
# ![](2024-02-04-01-27-15.png)

# %% [markdown]
# ![](2024-02-04-01-28-51.png)

# %% [markdown]
# ![](2024-02-04-01-28-14.png)

# %% [markdown]
# ## **Writing Useful Tests**

# %% [markdown]
# ![](2024-02-04-00-13-29.png)

# %% [markdown]
# ## **Testing Failures**

# %% [markdown]
# ![](2024-02-04-00-25-38.png)

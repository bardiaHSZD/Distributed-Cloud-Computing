# %% [markdown]
# # **Infrastructure as Code**

# %% [markdown]
# ## **Infrastructure as Code**

# %% [markdown]
# ![](2023-12-20-11-24-17.png)

# %% [markdown]
# ![](2023-12-20-11-24-38.png)

# %% [markdown]
# ![](2023-12-20-11-24-51.png)

# %% [markdown]
# ![](2023-12-20-11-25-21.png)

# %% [markdown]
# ![](2023-12-20-11-25-43.png)

# %% [markdown]
# ![](2023-12-20-11-26-36.png)

# %% [markdown]
# ![](2023-12-20-11-26-51.png)

# %% [markdown]
# ![](2023-12-20-11-27-03.png)

# %% [markdown]
# ![](2023-12-20-11-27-16.png)

# %% [markdown]
# ![](2023-12-20-11-39-03.png)

# %% [markdown]
# ![](2023-12-20-11-41-37.png)

# %% [markdown]
# ![](2023-12-20-12-05-59.png)

# %% [markdown]
# ![](2023-12-20-12-06-38.png)

# %% [markdown]
# ![](2023-12-20-12-07-01.png)

# %% [markdown]
# ![](2023-12-20-12-07-13.png)

# %% [markdown]
# ![](2023-12-20-12-07-35.png)

# %% [markdown]
# ![](2023-12-20-12-07-55.png)

# %% [markdown]
# ![](2023-12-20-12-09-06.png)

# %% [markdown]
# ![](2023-12-20-12-09-25.png)

# %% [markdown]
# ![](2023-12-20-12-09-36.png)

# %% [markdown]
# ![](2023-12-20-12-09-51.png)

# %% [markdown]
# ![](2023-12-20-12-10-10.png)

# %% [markdown]
# ![](2023-12-20-12-13-27.png)

# %% [markdown]
# ![](2023-12-20-12-13-44.png)

# %% [markdown]
# ![](2023-12-20-12-14-52.png)

# %% [markdown]
# ![](2023-12-20-12-15-04.png)

# %% [markdown]
# ![](2023-12-20-12-15-22.png)

# %% [markdown]
# ![](2023-12-20-12-15-37.png)

# %% [markdown]
# ![](2023-12-20-12-15-53.png)

# %% [markdown]
# ![](2023-12-20-12-16-24.png)

# %% [markdown]
# ![](2023-12-20-12-16-43.png)

# %% [markdown]
# ![](2023-12-20-12-17-24.png)

# %% [markdown]
# ![](2023-12-20-12-17-37.png)

# %% [markdown]
# ![](2023-12-20-12-17-47.png)

# %% [markdown]
# ![](2023-12-20-12-18-01.png)

# %% [markdown]
# ![](2023-12-20-12-18-37.png)

# %% [markdown]
# ![](2023-12-20-12-19-08.png)

# %% [markdown]
# ![](2023-12-20-12-20-19.png)

# %% [markdown]
# ![](2023-12-20-12-21-14.png)

# %% [markdown]
# ![](2023-12-20-12-21-33.png)

# %% [markdown]
# ![](2023-12-20-12-23-42.png)

# %% [markdown]
# ![](2023-12-20-12-24-05.png)

# %% [markdown]
# ![](2023-12-20-12-25-01.png)

# %% [markdown]
# ![](2023-12-20-12-25-15.png)

# %% [markdown]
# ![](2023-12-20-12-25-29.png)

# %% [markdown]
# ![](2023-12-20-12-25-42.png)

# %% [markdown]
# ![](2023-12-20-12-25-56.png)

# %% [markdown]
# ![](2023-12-20-12-26-15.png)

# %% [markdown]
# ![](2023-12-20-12-26-29.png)

# %% [markdown]
# ![](2023-12-20-12-26-51.png)

# %% [markdown]
# ![](2023-12-20-12-27-20.png)

# %% [markdown]
# ![](2023-12-20-12-27-30.png)

# %% [markdown]
# ![](2023-12-20-12-27-43.png)

# %% [markdown]
# ![](2023-12-20-12-28-14.png)

# %% [markdown]
# ![](2023-12-20-12-28-40.png)

# %% [markdown]
# ![](2023-12-20-12-28-54.png)

# %% [markdown]
# ![](2023-12-20-12-29-08.png)

# %% [markdown]
# ![](2023-12-20-12-30-29.png)

# %% [markdown]
# ![](2023-12-20-12-30-52.png)

# %% [markdown]
# ![](2023-12-20-12-31-03.png)

# %% [markdown]
# ![](2023-12-20-12-31-17.png)

# %% [markdown]
# ![](2023-12-20-12-31-29.png)

# %% [markdown]
# ![](2023-12-20-12-31-42.png)

# %% [markdown]
# ![](2023-12-20-12-34-23.png)

# %% [markdown]
# ![](2023-12-20-12-34-42.png)

# %% [markdown]
# ![](2023-12-20-12-35-16.png)

# %% [markdown]
# ![](2023-12-20-12-35-26.png)

# %% [markdown]
# ![](2023-12-20-12-35-37.png)

# %% [markdown]
# ![](2023-12-20-12-35-50.png)

# %% [markdown]
# ![](2023-12-20-12-36-08.png)

# %% [markdown]
# ![](2023-12-20-12-36-19.png)

# %% [markdown]
# ![](2023-12-20-12-36-29.png)

# %% [markdown]
# ![](2023-12-20-12-38-27.png)

# %% [markdown]
# ![](2023-12-20-12-38-38.png)

# %% [markdown]
# ![](2023-12-20-12-38-49.png)

# %% [markdown]
# ![](2023-12-20-12-39-00.png)

# %% [markdown]
# ![](2023-12-20-12-39-32.png)

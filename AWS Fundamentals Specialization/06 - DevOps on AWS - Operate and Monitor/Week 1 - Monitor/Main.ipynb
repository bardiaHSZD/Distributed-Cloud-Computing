# %% [markdown]
# # **Monitor**

# %% [markdown]
# ![](2023-12-20-13-28-32.png)

# %% [markdown]
# ![](2023-12-20-13-29-28.png)

# %% [markdown]
# ![](2023-12-20-13-29-39.png)

# %% [markdown]
# ![](2023-12-20-13-29-49.png)

# %% [markdown]
# ![](2023-12-20-13-30-09.png)

# %% [markdown]
# ![](2023-12-20-13-30-27.png)

# %% [markdown]
# ![](2023-12-20-13-30-47.png)

# %% [markdown]
# ![](2023-12-20-13-30-59.png)

# %% [markdown]
# ![](2023-12-20-13-31-08.png)

# %% [markdown]
# ![](2023-12-20-13-32-05.png)

# %% [markdown]
# ![](2023-12-20-13-32-56.png)

# %% [markdown]
# ![](2023-12-20-13-33-16.png)

# %% [markdown]
# ![](2023-12-20-13-33-26.png)

# %% [markdown]
# ![](2023-12-20-13-33-38.png)

# %% [markdown]
# ![](2023-12-20-13-34-16.png)

# %% [markdown]
# ![](2023-12-20-13-34-28.png)

# %% [markdown]
# ![](2023-12-20-13-35-01.png)

# %% [markdown]
# ![](2023-12-20-13-35-16.png)

# %% [markdown]
# ![](2023-12-20-13-35-34.png)

# %% [markdown]
# ![](2023-12-20-13-35-53.png)

# %% [markdown]
# ![](2023-12-20-13-36-10.png)

# %% [markdown]
# ![](2023-12-20-13-36-25.png)

# %% [markdown]
# ![](2023-12-20-13-36-40.png)

# %% [markdown]
# ![](2023-12-20-13-37-10.png)

# %% [markdown]
# ![](2023-12-20-13-37-21.png)

# %% [markdown]
# ![](2023-12-20-13-41-07.png)

# %% [markdown]
# ![](2023-12-20-13-41-25.png)

# %% [markdown]
# ![](2023-12-20-13-41-48.png)

# %% [markdown]
# ![](2023-12-20-13-42-00.png)

# %% [markdown]
# ![](2023-12-20-13-42-23.png)

# %% [markdown]
# ![](2023-12-20-13-42-36.png)

# %% [markdown]
# ![](2023-12-20-13-42-47.png)

# %% [markdown]
# ![](2023-12-20-13-42-57.png)

# %% [markdown]
# ## **How to Monitor Different Areas**

# %% [markdown]
# ![](2023-12-20-13-43-49.png)

# %% [markdown]
# ![](2023-12-20-13-45-19.png)

# %% [markdown]
# and applications.

# %% [markdown]
# ![](2023-12-20-13-45-47.png)

# %% [markdown]
# ![](2023-12-20-13-46-32.png)

# %% [markdown]
# ![](2023-12-20-13-47-21.png)

# %% [markdown]
# ![](2023-12-20-13-59-11.png)

# %% [markdown]
# ![](2023-12-20-13-59-26.png)

# %% [markdown]
# ![](2023-12-20-14-00-39.png)

# %% [markdown]
# ![](2023-12-20-14-01-12.png)

# %% [markdown]
# ![](2023-12-20-14-01-31.png)

# %% [markdown]
# ![](2023-12-20-14-01-49.png)

# %% [markdown]
# ![](2023-12-20-14-02-52.png)

# %% [markdown]
# ![](2023-12-20-14-03-34.png)

# %% [markdown]
# ![](2023-12-20-14-03-55.png)

# %% [markdown]
# ![](2023-12-20-14-04-29.png)

# %% [markdown]
# ![](2023-12-20-14-04-50.png)

# %% [markdown]
# ![](2023-12-20-14-05-24.png)

# %% [markdown]
# ![](2023-12-20-14-05-46.png)

# %% [markdown]
# ![](2023-12-20-14-06-07.png)

# %% [markdown]
# ![](2023-12-20-14-06-26.png)

# %% [markdown]
# ![](2023-12-20-14-06-37.png)

# %% [markdown]
# ![](2023-12-20-14-06-48.png)

# %% [markdown]
# ![](2023-12-20-14-07-47.png)

# %% [markdown]
# ![](2023-12-20-14-11-47.png)

# %% [markdown]
# ![](2023-12-20-14-12-14.png)

# %% [markdown]
# ![](2023-12-20-14-12-27.png)

# %% [markdown]
# ![](2023-12-20-14-14-31.png)

# %% [markdown]
# ![](2023-12-20-14-14-44.png)

# %% [markdown]
# ![](2023-12-20-14-15-01.png)

# %% [markdown]
# ![](2023-12-20-14-15-22.png)

# %% [markdown]
# ![](2023-12-20-14-15-41.png)

# %% [markdown]
# ![](2023-12-20-14-17-05.png)

# %% [markdown]
# ![](2023-12-20-14-18-05.png)

# %% [markdown]
# ![](2023-12-20-14-18-26.png)

# %% [markdown]
# ![](2023-12-20-14-18-41.png)

# %% [markdown]
# ![](2023-12-20-14-22-41.png)

# %% [markdown]
# ![](2023-12-20-14-23-15.png)

# %% [markdown]
# ![](2023-12-20-14-23-35.png)

# %% [markdown]
# ![](2023-12-20-14-23-53.png)

# %% [markdown]
# ![](2023-12-20-14-24-12.png)

# %% [markdown]
# ![](2023-12-20-14-24-25.png)

# %% [markdown]
# ![](2023-12-20-14-24-50.png)

# %% [markdown]
# ![](2023-12-20-14-25-05.png)

# %% [markdown]
# ![](2023-12-20-14-25-19.png)

# %% [markdown]
# ![](2023-12-20-14-25-41.png)

# %% [markdown]
# ![](2023-12-20-14-25-57.png)

# %% [markdown]
# ![](2023-12-20-14-26-46.png)

# %% [markdown]
# ![](2023-12-20-14-28-26.png)

# %% [markdown]
# ![](2023-12-20-14-28-59.png)

# %% [markdown]
# ![](2023-12-20-14-29-11.png)

# %% [markdown]
# ![](2023-12-20-14-29-24.png)

# %% [markdown]
# ![](2023-12-20-14-27-20.png)

# %% [markdown]
# ![](2023-12-20-14-27-30.png)

# %% [markdown]
# ![](2023-12-20-14-27-43.png)

# %% [markdown]
# ![](2023-12-20-14-27-54.png)

# %% [markdown]
# ![](2023-12-20-14-30-24.png)

# %% [markdown]
# ![](2023-12-20-14-30-41.png)

# %% [markdown]
# ![](2023-12-20-14-31-08.png)

# %% [markdown]
# ![](2023-12-20-14-31-32.png)

# %% [markdown]
# ![](2023-12-20-14-31-55.png)

# %% [markdown]
# ![](2023-12-20-14-32-07.png)

# %% [markdown]
# ![](2023-12-20-14-32-23.png)

# %% [markdown]
# ![](2023-12-20-14-32-37.png)

# %% [markdown]
# ![](2023-12-20-14-33-02.png)

# %% [markdown]
# ![](2023-12-20-14-33-16.png)

# %% [markdown]
# ![](2023-12-20-14-34-15.png)

# %% [markdown]
# ![](2023-12-20-14-35-07.png)

# %% [markdown]
# ![](2023-12-20-14-35-39.png)

# %% [markdown]
# ![](2023-12-20-14-36-22.png)

# %% [markdown]
# ![](2023-12-20-14-36-52.png)

# %% [markdown]
# ![](2023-12-20-14-37-27.png)

# %% [markdown]
# ![](2023-12-20-14-37-58.png)

# %% [markdown]
# ![](2023-12-20-14-38-51.png)

# %% [markdown]
# ![](2023-12-20-14-39-25.png)

# %% [markdown]
# ![](2023-12-20-14-39-43.png)

# %% [markdown]
# ![](2023-12-20-14-40-14.png)

# %% [markdown]
# ![](2023-12-20-14-40-32.png)

# %% [markdown]
# ![](2023-12-20-14-40-52.png)

# %% [markdown]
# ![](2023-12-20-14-41-22.png)

# %% [markdown]
# ![](2023-12-20-14-41-55.png)

# %% [markdown]
# ![](2023-12-20-14-42-07.png)

# %% [markdown]
# ![](2023-12-20-14-44-35.png)

# %% [markdown]
# ![](2023-12-20-14-46-09.png)

# %% [markdown]
# ![](2023-12-20-14-46-30.png)

# %% [markdown]
# ![](2023-12-20-14-46-42.png)

# %% [markdown]
# ![](2023-12-20-14-47-09.png)

# %% [markdown]
# ![](2023-12-20-14-47-45.png)

# %% [markdown]
# ![](2023-12-20-14-48-07.png)

# %% [markdown]
# ![](2023-12-20-14-48-43.png)

# %% [markdown]
# ![](2023-12-20-14-48-53.png)

# %% [markdown]
# ![](2023-12-20-14-49-26.png)

# %% [markdown]
# ![](2023-12-20-14-49-44.png)

# %% [markdown]
# ![](2023-12-20-14-49-58.png)

# %% [markdown]
# ![](2023-12-20-14-50-22.png)

# %% [markdown]
# ![](2023-12-20-14-50-39.png)

# %% [markdown]
# which are batched to S3.

# %% [markdown]
# ![](2023-12-20-14-50-57.png)

# %% [markdown]
# ![](2023-12-20-14-51-44.png)

# %% [markdown]
# ![](2023-12-20-14-52-12.png)

# %% [markdown]
# ![](2023-12-20-14-52-57.png)

# %% [markdown]
# ## **Hands-on Inside Student's Account**

# %% [markdown]
# ![](2023-12-20-14-54-03.png)

# %% [markdown]
# ![](2023-12-20-14-53-50.png)

# %% [markdown]
# ![](2023-12-20-14-55-48.png)

# %% [markdown]
# **Week Recap**
#
# During the first week of the third course on the DevOps Series, you have learned what is the Monitoring value proposition and why instrumenting your environments is helpful.
#
# The week’s content was divided into Cloud, Application and Networking environments, with the corresponding AWS Services to apply monitoring to give you insights on what’s going on with your Cloud environments. The instructors covered services and features such as CloudWatch Metrics, Alarms and Logs, in addition to VPC Flow Logs, AWS X-Ray, Amazon EventBridge, AWS Config and AWS CloudTrail.
#
# At the end of the week, we offered an optional hands-on exercise, where you may have learned about topics and best-practices you can perform in your own environments. The exercise covered how to be notified when the CodePipeline status changes, which could be instrumental for posting a message into a chat room in case of the pipeline getting stuck!
#
# You are almost there! Please continue your DevOps journey towards the next and last week of the DevOps on AWS Series, the week where we will cover Operations and AWS Systems Manager in depth!

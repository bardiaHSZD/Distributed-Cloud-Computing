# %% [markdown]
# # **Storage and Databases on AWS**

# %% [markdown]
# ## **Storage on AWS**

# %% [markdown]
# ![](2023-12-15-15-03-23.png)

# %% [markdown]
# ![](2023-12-15-15-04-03.png)

# %% [markdown]
# ![](2023-12-15-15-04-24.png)

# %% [markdown]
# ![](2023-12-15-15-05-47.png)

# %% [markdown]
# ![](2023-12-15-15-06-23.png)

# %% [markdown]
# ![](2023-12-15-15-06-40.png)

# %% [markdown]
# ![](2023-12-15-15-06-58.png)

# %% [markdown]
# ![](2023-12-15-15-07-15.png)

# %% [markdown]
# ![](2023-12-15-15-07-30.png)

# %% [markdown]
# ![](2023-12-15-15-08-32.png)

# %% [markdown]
# ![](2023-12-15-15-08-55.png)

# %% [markdown]
# ![](2023-12-15-15-09-22.png)

# %% [markdown]
# **Relate Back to Traditional Storage Systems**
#
# If you’ve worked with storage on-premises, you may already be familiar with block, file, and object storage. Consider the following technologies and how they relate to systems you may have seen before.
#
# - Block storage in the cloud is analogous to direct-attached storage (DAS) or a storage area network (SAN).
#
# - File storage systems are often supported with a network attached storage (NAS) server.
#
# Adding more storage in a traditional data center environment is a more rigid process, as you need to purchase, install, and configure these storage solutions. With cloud computing, the process is more flexible. You can create, delete, and modify storage solutions all within a matter of minutes.

# %% [markdown]
# ![](2023-12-15-15-16-25.png)

# %% [markdown]
# ![](2023-12-15-15-16-54.png)

# %% [markdown]
# ![](2023-12-15-15-17-26.png)

# %% [markdown]
# ![](2023-12-15-15-17-48.png)

# %% [markdown]
# ![](2023-12-15-15-21-00.png)

# %% [markdown]
# ![](2023-12-15-15-21-14.png)

# %% [markdown]
# ![](2023-12-15-15-22-00.png)

# %% [markdown]
# ![](2023-12-15-15-22-27.png)

# %% [markdown]
# ![](2023-12-15-15-22-44.png)

# %% [markdown]
# ![](2023-12-15-15-23-56.png)

# %% [markdown]
# ![](2023-12-15-15-24-55.png)

# %% [markdown]
# ![](2023-12-15-15-25-11.png)

# %% [markdown]
# ![](2023-12-15-15-26-03.png)

# %% [markdown]
# ![](2023-12-15-15-26-13.png)

# %% [markdown]
# ![](2023-12-15-15-26-39.png)

# %% [markdown]
# ![](2023-12-15-15-27-18.png)

# %% [markdown]
# ![](2023-12-15-15-27-35.png)

# %% [markdown]
# ![](2023-12-15-15-27-56.png)

# %% [markdown]
# ![](2023-12-15-15-28-18.png)

# %% [markdown]
# ![](2023-12-15-18-36-16.png)

# %% [markdown]
# ![](2023-12-15-18-36-43.png)

# %% [markdown]
# ![](2023-12-15-18-37-04.png)

# %% [markdown]
# ![](2023-12-15-18-37-25.png)

# %% [markdown]
# ![](2023-12-15-18-37-44.png)

# %% [markdown]
# ![](2023-12-15-18-37-55.png)

# %% [markdown]
# ![](2023-12-15-18-38-16.png)

# %% [markdown]
# ![](2023-12-15-18-38-45.png)

# %% [markdown]
# ![](2023-12-15-18-39-04.png)

# %% [markdown]
# ![](2023-12-15-18-40-00.png)

# %% [markdown]
# ![](2023-12-15-18-40-41.png)

# %% [markdown]
# ![](2023-12-15-18-41-36.png)

# %% [markdown]
# ![](2023-12-15-18-41-51.png)

# %% [markdown]
# ![](2023-12-15-18-42-06.png)

# %% [markdown]
# ![](2023-12-15-18-42-35.png)

# %% [markdown]
# ![](2023-12-15-18-42-51.png)

# %% [markdown]
# ![](2023-12-15-18-43-30.png)

# %% [markdown]
# ![](2023-12-15-18-44-09.png)

# %% [markdown]
# ![](2023-12-15-18-44-33.png)

# %% [markdown]
# ![](2023-12-15-18-47-46.png)

# %% [markdown]
# ![](2023-12-15-18-48-03.png)

# %% [markdown]
# ![](2023-12-15-18-48-16.png)

# %% [markdown]
# ![](2023-12-15-18-48-32.png)

# %% [markdown]
# ![](2023-12-15-18-48-54.png)

# %% [markdown]
# ![](2023-12-15-18-49-18.png)

# %% [markdown]
# ![](2023-12-15-18-51-06.png)

# %% [markdown]
# ![](2023-12-15-18-51-21.png)

# %% [markdown]
# ![](2023-12-15-18-51-36.png)

# %% [markdown]
# ![](2023-12-15-18-52-08.png)

# %% [markdown]
# ![](2023-12-15-18-52-20.png)

# %% [markdown]
# ![](2023-12-15-18-52-34.png)

# %% [markdown]
# ![](2023-12-15-18-53-02.png)

# %% [markdown]
# ![](2023-12-15-18-53-23.png)

# %% [markdown]
# ![](2023-12-15-18-53-39.png)

# %% [markdown]
# ![](2023-12-15-18-53-50.png)

# %% [markdown]
# ![](2023-12-15-18-54-03.png)

# %% [markdown]
# ![](2023-12-15-18-54-32.png)

# %% [markdown]
# ![](2023-12-15-18-54-51.png)

# %% [markdown]
# ![](2023-12-15-18-55-16.png)

# %% [markdown]
# ![](2023-12-15-18-56-22.png)

# %% [markdown]
# ## **Databes on AWS**

# %% [markdown]
# ## **Exercise and Assessment**

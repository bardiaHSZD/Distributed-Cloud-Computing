# %% [markdown]
# # **Continuous Integration and Continuous Delivery**

# %% [markdown]
# ## **Testing and Automation**

# %% [markdown]
# ## **Building Pipelines**

# %% [markdown]
# ## **Assessment and Discussion**
